# %% [markdown]
# # Feature Engineering
#
# The goals of this course are to:
#
# -   Understand the importance of feature engineering
# -   Learn how to create new features from existing data
# -   Learn how to use domain knowledge to create new features
# -   Learn how to encode categorical variables for machine learning
# -   Learn how to handle missing values in a dataset
# -   Learn how to deal with time series data
# -   Learn how to scale features for machine learning
# -   Learn how to evaluate features
# -   Learn how to use Pandas and Scikit-Learn to engineer features

# %% [markdown]
# # Basic Techniques

# %% [markdown]
# ## Imputation
#
# *Imputation* means to fill in missing values with plausible values. There are many
# options:
#
# -  A constant value that has meaning within the domain, such as 0, distinct from all
#     other values.
# -  A value from another randomly selected record.
# -  A mean, median or mode value for the column.
# -  A value estimated by another predictive model.
#
# We use imputation because many machine learning algorithms do not support missing values. Modern algorithms like XGBoost handle missing values themselves, but it is still a common practice to impute because other algorithms do not.

# %% [markdown]
# ## Load Data
#
# Fuel economy data from the U.S. Environmental Protection Agency (EPA) for 2019 model year vehicles. The data are available in a CSV file with 82,000 rows and 83 columns.
#
# https://www.fueleconomy.gov/feg/epadata/vehicles.csv

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /usr/local/python/3.12.1/lib/python3.12/site-packages (24.0.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
url = 'https://www.fueleconomy.gov/feg/epadata/vehicles.csv' 

raw = pd.read_csv(url)#, dtype_backend='pyarrow', engine='pyarrow')
# Out:
# /tmp/ipykernel_3681/794973991.py:4: DtypeWarning: Columns (69,71,72,73,74,75,77,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw = pd.read_csv(url)#, dtype_backend='pyarrow', engine='pyarrow')

# %%
raw
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      14.167143         0.0        0.0        0.0      19      0.0        0
# 1      27.046364         0.0        0.0        0.0       9      0.0        0
# 2      11.018889         0.0        0.0        0.0      23      0.0        0
# 3      27.046364         0.0        0.0        0.0      10      0.0        0
# 4      15.658421         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 49841  13.523182         0.0        0.0        0.0      19      0.0        0
# 49842  12.935217         0.0        0.0        0.0      20      0.0        0
# 49843  14.167143         0.0        0.0        0.0      18      0.0        0
# 49844  14.167143         0.0        0.0        0.0      18      0.0        0
# 49845  16.528333         0.0        0.0        0.0      16      0.0        0
#
#        cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...         ...     ...    ...  ...      ...       ...         ...        ...
# 49841       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 49842       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 49843       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 49844       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 49845       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                           createdOn                    modifiedOn  startStop  \
# 0      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 1      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 2      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 3      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 4      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# ...                             ...                           ...        ...
# 49841  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 49842  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 49843  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 49844  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 49845  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
#
#        phevCity  phevHwy  phevComb
# 0             0        0         0
# 1             0        0         0
# 2             0        0         0
# 3             0        0         0
# 4             0        0         0
# ...         ...      ...       ...
# 49841         0        0         0
# 49842         0        0         0
# 49843         0        0         0
# 49844         0        0         0
# 49845         0        0         0
#
# [49846 rows x 84 columns]

# %%
raw.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'baseModel',
#        'guzzler', 'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2',
#        'rangeA', 'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
#        'createdOn', 'modifiedOn', 'startStop', 'phevCity', 'phevHwy',
#        'phevComb'],
#       dtype='object')

# %%
cols = ['year', 'make', 'model', 'trany', 'drive', 'VClass', 'eng_dscr',
    'barrels08', 'city08', 'comb08', 'range', 'evMotor', 'cylinders', 'displ', 'fuelCost08', 
        'fuelType', 'highway08',  'trans_dscr','createdOn']

def to_tz(df_, time_col, tz_offset, tz_name):
    return (df_
            .groupby(tz_offset)
            [time_col]
            .transform(lambda s: pd.to_datetime(s)
                       .dt.tz_localize(s.name, ambiguous=True)
                       .dt.tz_convert(tz_name))
            )

autos = (raw.loc[:, cols]
         .assign(
            offset=(raw.createdOn.str.extract(r'\d\d:\d\d (?P<offset>[A-Z]{3}?)')
                .replace('EDT', 'EST5EDT')),
            str_date=(raw.createdOn.str.slice(4,19) + ' ' +
                raw.createdOn.str.slice(-4)),
            createdOn=lambda df_: to_tz(df_, 'str_date', 'offset', 'America/New_York')
         )
)
autos.dtypes
# Out:
# year                                     int64
# make                                    object
# model                                   object
# trany                                   object
# drive                                   object
# VClass                                  object
# eng_dscr                                object
# barrels08                              float64
# city08                                   int64
# comb08                                   int64
# range                                    int64
# evMotor                                 object
# cylinders                              float64
# displ                                  float64
# fuelCost08                               int64
# fuelType                                object
# highway08                                int64
# trans_dscr                              object
# createdOn     datetime64[ns, America/New_York]
# offset                                  object
# str_date                                object
# dtype: object

# %%
# key insight in Python
# booleans are integers

True + 41
# Out:
# 42

# %%
False + 41
# Out:
# 41

# %%
# determining missing values
(autos
 .isna()
 #.sum()
 .mean().mul(100).round(1)
 )
# Out:
# year           0.0
# make           0.0
# model          0.0
# trany          0.0
# drive          2.4
# VClass         0.0
# eng_dscr      36.5
# barrels08      0.0
# city08         0.0
# comb08         0.0
# range          0.0
# evMotor       93.1
# cylinders      3.0
# displ          2.9
# fuelCost08     0.0
# fuelType       0.0
# highway08      0.0
# trans_dscr    69.8
# createdOn      0.0
# offset         0.0
# str_date       0.0
# dtype: float64

# %%
(raw
 #.select_dtypes('string[pyarrow]')
 .select_dtypes(object)
 .isna()
 .sum()
)
# Out:
# drive          1186
# eng_dscr      18209
# fuelType          0
# fuelType1         1
# make              0
# model             0
# mpgData           0
# trany            11
# VClass            0
# baseModel         0
# guzzler       47013
# trans_dscr    34802
# tCharger      38314
# sCharger      48702
# atvType       43296
# fuelType2     47838
# rangeA        47842
# evMotor       46399
# mfrCode       30808
# c240Dscr      49705
# c240bDscr     49711
# createdOn         0
# modifiedOn        0
# startStop     31689
# dtype: int64

# %% [markdown]
# ## Filling in Missing Values

# %%
# where are cylinders missing?

(autos
 .query('cylinders.isna()')
 )
# Out:
#        year    make                      model  \
# 7138   2000  Nissan                   Altra EV
# 7139   2000  Toyota                    RAV4 EV
# 8143   2001  Toyota                    RAV4 EV
# 8144   2001    Ford                      Th!nk
# 8146   2001    Ford     Explorer USPS Electric
# ...     ...     ...                        ...
# 44321  2026  Toyota  bZ Woodland AWD 235/60R18
# 44322  2026  Toyota  bZ Woodland AWD 235/65R18
# 44323  2026  Toyota            C-HR AWD 18inch
# 44324  2026  Toyota            C-HR AWD 20inch
# 44328  2026  Toyota                      Mirai
#
#                                   trany             drive  \
# 7138                                NaN               NaN
# 7139                                NaN     2-Wheel Drive
# 8143                                NaN     2-Wheel Drive
# 8144                                NaN               NaN
# 8146                                NaN     2-Wheel Drive
# ...                                 ...               ...
# 44321                    Automatic (A1)   All-Wheel Drive
# 44322                    Automatic (A1)   All-Wheel Drive
# 44323                    Automatic (A1)   All-Wheel Drive
# 44324                    Automatic (A1)   All-Wheel Drive
# 44328  Automatic (variable gear ratios)  Rear-Wheel Drive
#
#                                 VClass eng_dscr  barrels08  city08  comb08  \
# 7138            Midsize Station Wagons      NaN     0.0960      81      85
# 7139       Sport Utility Vehicle - 2WD      NaN     0.1128      81      72
# 8143       Sport Utility Vehicle - 2WD      NaN     0.1128      81      72
# 8144                       Two Seaters      NaN     0.1248      74      65
# 8146       Sport Utility Vehicle - 2WD      NaN     0.2088      45      39
# ...                                ...      ...        ...     ...     ...
# 44321  Small Sport Utility Vehicle 4WD      NaN     0.0696     127     117
# 44322  Small Sport Utility Vehicle 4WD      NaN     0.0744     117     109
# 44323  Small Sport Utility Vehicle 4WD      NaN     0.0696     127     117
# 44324  Small Sport Utility Vehicle 4WD      NaN     0.0720     122     112
# 44328                     Compact Cars     PEFC     1.9548      74      72
#
#        ...                       evMotor cylinders  displ  fuelCost08  \
# 7138   ...            62 KW AC Induction       NaN    NaN         900
# 7139   ...                      50 KW DC       NaN    NaN        1050
# 8143   ...                      50 KW DC       NaN    NaN        1050
# 8144   ...            27 KW AC Induction       NaN    NaN        1150
# 8146   ...            67 KW AC Induction       NaN    NaN        1950
# ...    ...                           ...       ...    ...         ...
# 44321  ...         167 kW AC Synchronous       NaN    NaN         650
# 44322  ...         167 kW AC Synchronous       NaN    NaN         700
# 44323  ...  87 and 167 kW AC Synchronous       NaN    NaN         650
# 44324  ...  87 and 167 kW AC Synchronous       NaN    NaN         650
# 44328  ...         134 kW AC Synchronous       NaN    NaN           0
#
#           fuelType highway08  trans_dscr                 createdOn   offset  \
# 7138   Electricity        91         NaN 2013-01-01 00:00:00-05:00      EST
# 7139   Electricity        64         NaN 2013-01-01 00:00:00-05:00      EST
# 8143   Electricity        64         NaN 2013-01-01 00:00:00-05:00      EST
# 8144   Electricity        58         NaN 2013-01-01 00:00:00-05:00      EST
# 8146   Electricity        33         NaN 2013-01-01 00:00:00-05:00      EST
# ...            ...       ...         ...                       ...      ...
# 44321  Electricity       107         NaN 2026-03-18 00:00:00-04:00  EST5EDT
# 44322  Electricity       100         NaN 2026-03-18 00:00:00-04:00  EST5EDT
# 44323  Electricity       107         NaN 2026-03-18 00:00:00-04:00  EST5EDT
# 44324  Electricity       102         NaN 2026-03-18 00:00:00-04:00  EST5EDT
# 44328     Hydrogen        70         NaN 2026-03-18 00:00:00-04:00  EST5EDT
#
#                    str_date
# 7138   Jan 01 00:00:00 2013
# 7139   Jan 01 00:00:00 2013
# 8143   Jan 01 00:00:00 2013
# 8144   Jan 01 00:00:00 2013
# 8146   Jan 01 00:00:00 2013
# ...                     ...
# 44321  Mar 18 00:00:00 2026
# 44322  Mar 18 00:00:00 2026
# 44323  Mar 18 00:00:00 2026
# 44324  Mar 18 00:00:00 2026
# 44328  Mar 18 00:00:00 2026
#
# [1471 rows x 21 columns]

# %%
(autos
 .assign(cylinders=autos.cylinders.fillna(0))
)
# Out:
#        year        make                model            trany  \
# 0      1985  Alfa Romeo   Spider Veloce 2000     Manual 5-spd
# 1      1985     Ferrari           Testarossa     Manual 5-spd
# 2      1985       Dodge              Charger     Manual 5-spd
# 3      1985       Dodge  B150/B250 Wagon 2WD  Automatic 3-spd
# 4      1993      Subaru     Legacy AWD Turbo     Manual 5-spd
# ...     ...         ...                  ...              ...
# 49841  1993      Subaru               Legacy  Automatic 4-spd
# 49842  1993      Subaru               Legacy     Manual 5-spd
# 49843  1993      Subaru           Legacy AWD  Automatic 4-spd
# 49844  1993      Subaru           Legacy AWD     Manual 5-spd
# 49845  1993      Subaru     Legacy AWD Turbo  Automatic 4-spd
#
#                             drive           VClass    eng_dscr  barrels08  \
# 0                Rear-Wheel Drive      Two Seaters       (FFS)  14.167143
# 1                Rear-Wheel Drive      Two Seaters   (GUZZLER)  27.046364
# 2               Front-Wheel Drive  Subcompact Cars       (FFS)  11.018889
# 3                Rear-Wheel Drive             Vans         NaN  27.046364
# 4      4-Wheel or All-Wheel Drive     Compact Cars  (FFS,TRBO)  15.658421
# ...                           ...              ...         ...        ...
# 49841           Front-Wheel Drive     Compact Cars       (FFS)  13.523182
# 49842           Front-Wheel Drive     Compact Cars       (FFS)  12.935217
# 49843  4-Wheel or All-Wheel Drive     Compact Cars       (FFS)  14.167143
# 49844  4-Wheel or All-Wheel Drive     Compact Cars       (FFS)  14.167143
# 49845  4-Wheel or All-Wheel Drive     Compact Cars  (FFS,TRBO)  16.528333
#
#        city08  comb08  ...  evMotor cylinders  displ  fuelCost08  fuelType  \
# 0          19      21  ...      NaN       4.0    2.0        2850   Regular
# 1           9      11  ...      NaN      12.0    4.9        5450   Regular
# 2          23      27  ...      NaN       4.0    2.2        2200   Regular
# 3          10      11  ...      NaN       8.0    5.2        5450   Regular
# 4          17      19  ...      NaN       4.0    2.2        3650   Premium
# ...       ...     ...  ...      ...       ...    ...         ...       ...
# 49841      19      22  ...      NaN       4.0    2.2        2700   Regular
# 49842      20      23  ...      NaN       4.0    2.2        2600   Regular
# 49843      18      21  ...      NaN       4.0    2.2        2850   Regular
# 49844      18      21  ...      NaN       4.0    2.2        2850   Regular
# 49845      16      18  ...      NaN       4.0    2.2        3850   Premium
#
#       highway08  trans_dscr                 createdOn offset  \
# 0            25         NaN 2013-01-01 00:00:00-05:00    EST
# 1            14         NaN 2013-01-01 00:00:00-05:00    EST
# 2            33         SIL 2013-01-01 00:00:00-05:00    EST
# 3            12         NaN 2013-01-01 00:00:00-05:00    EST
# 4            23         NaN 2013-01-01 00:00:00-05:00    EST
# ...         ...         ...                       ...    ...
# 49841        26       CLKUP 2013-01-01 00:00:00-05:00    EST
# 49842        28         NaN 2013-01-01 00:00:00-05:00    EST
# 49843        24       CLKUP 2013-01-01 00:00:00-05:00    EST
# 49844        24         NaN 2013-01-01 00:00:00-05:00    EST
# 49845        21       CLKUP 2013-01-01 00:00:00-05:00    EST
#
#                    str_date
# 0      Jan 01 00:00:00 2013
# 1      Jan 01 00:00:00 2013
# 2      Jan 01 00:00:00 2013
# 3      Jan 01 00:00:00 2013
# 4      Jan 01 00:00:00 2013
# ...                     ...
# 49841  Jan 01 00:00:00 2013
# 49842  Jan 01 00:00:00 2013
# 49843  Jan 01 00:00:00 2013
# 49844  Jan 01 00:00:00 2013
# 49845  Jan 01 00:00:00 2013
#
# [49846 rows x 21 columns]

# %%
# Create sklearn pipeline to fill in missing cylinders with 0

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# set output to pandas
from sklearn import set_config
set_config(transform_output='pandas')

# create pipeline for cylinders
cyl_pipe = Pipeline([
    ('impute', SimpleImputer(strategy='constant', fill_value=0)),
])

# try it out
cyl_pipe.fit_transform(autos[['cylinders']])
# Out:
#        cylinders
# 0            4.0
# 1           12.0
# 2            4.0
# 3            8.0
# 4            4.0
# ...          ...
# 49841        4.0
# 49842        4.0
# 49843        4.0
# 49844        4.0
# 49845        4.0
#
# [49846 rows x 1 columns]

# %%
# see where it fill in missing values
(cyl_pipe
 .fit_transform(autos[['cylinders']])
 .loc[autos.cylinders.isna()]
)
# Out:
#        cylinders
# 7138         0.0
# 7139         0.0
# 8143         0.0
# 8144         0.0
# 8146         0.0
# ...          ...
# 44321        0.0
# 44322        0.0
# 44323        0.0
# 44324        0.0
# 44328        0.0
#
# [1471 rows x 1 columns]

# %%
# create more realistic pipeline
# set missing cylinders to 0 and displ to median
from sklearn.compose import ColumnTransformer
cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ'])
    ],
    remainder='passthrough'
)

# Create the pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

# Fit and transform the data
pipeline.fit_transform(autos)
# Out:
#        cyl_imputer__cylinders  displ_imputer__displ  remainder__year  \
# 0                         4.0                   2.0             1985
# 1                        12.0                   4.9             1985
# 2                         4.0                   2.2             1985
# 3                         8.0                   5.2             1985
# 4                         4.0                   2.2             1993
# ...                       ...                   ...              ...
# 49841                     4.0                   2.2             1993
# 49842                     4.0                   2.2             1993
# 49843                     4.0                   2.2             1993
# 49844                     4.0                   2.2             1993
# 49845                     4.0                   2.2             1993
#
#       remainder__make     remainder__model remainder__trany  \
# 0          Alfa Romeo   Spider Veloce 2000     Manual 5-spd
# 1             Ferrari           Testarossa     Manual 5-spd
# 2               Dodge              Charger     Manual 5-spd
# 3               Dodge  B150/B250 Wagon 2WD  Automatic 3-spd
# 4              Subaru     Legacy AWD Turbo     Manual 5-spd
# ...               ...                  ...              ...
# 49841          Subaru               Legacy  Automatic 4-spd
# 49842          Subaru               Legacy     Manual 5-spd
# 49843          Subaru           Legacy AWD  Automatic 4-spd
# 49844          Subaru           Legacy AWD     Manual 5-spd
# 49845          Subaru     Legacy AWD Turbo  Automatic 4-spd
#
#                  remainder__drive remainder__VClass remainder__eng_dscr  \
# 0                Rear-Wheel Drive       Two Seaters               (FFS)
# 1                Rear-Wheel Drive       Two Seaters           (GUZZLER)
# 2               Front-Wheel Drive   Subcompact Cars               (FFS)
# 3                Rear-Wheel Drive              Vans                 NaN
# 4      4-Wheel or All-Wheel Drive      Compact Cars          (FFS,TRBO)
# ...                           ...               ...                 ...
# 49841           Front-Wheel Drive      Compact Cars               (FFS)
# 49842           Front-Wheel Drive      Compact Cars               (FFS)
# 49843  4-Wheel or All-Wheel Drive      Compact Cars               (FFS)
# 49844  4-Wheel or All-Wheel Drive      Compact Cars               (FFS)
# 49845  4-Wheel or All-Wheel Drive      Compact Cars          (FFS,TRBO)
#
#        remainder__barrels08  ...  remainder__comb08  remainder__range  \
# 0                 14.167143  ...                 21                 0
# 1                 27.046364  ...                 11                 0
# 2                 11.018889  ...                 27                 0
# 3                 27.046364  ...                 11                 0
# 4                 15.658421  ...                 19                 0
# ...                     ...  ...                ...               ...
# 49841             13.523182  ...                 22                 0
# 49842             12.935217  ...                 23                 0
# 49843             14.167143  ...                 21                 0
# 49844             14.167143  ...                 21                 0
# 49845             16.528333  ...                 18                 0
#
#        remainder__evMotor remainder__fuelCost08  remainder__fuelType  \
# 0                     NaN                  2850              Regular
# 1                     NaN                  5450              Regular
# 2                     NaN                  2200              Regular
# 3                     NaN                  5450              Regular
# 4                     NaN                  3650              Premium
# ...                   ...                   ...                  ...
# 49841                 NaN                  2700              Regular
# 49842                 NaN                  2600              Regular
# 49843                 NaN                  2850              Regular
# 49844                 NaN                  2850              Regular
# 49845                 NaN                  3850              Premium
#
#       remainder__highway08  remainder__trans_dscr      remainder__createdOn  \
# 0                       25                    NaN 2013-01-01 00:00:00-05:00
# 1                       14                    NaN 2013-01-01 00:00:00-05:00
# 2                       33                    SIL 2013-01-01 00:00:00-05:00
# 3                       12                    NaN 2013-01-01 00:00:00-05:00
# 4                       23                    NaN 2013-01-01 00:00:00-05:00
# ...                    ...                    ...                       ...
# 49841                   26                  CLKUP 2013-01-01 00:00:00-05:00
# 49842                   28                    NaN 2013-01-01 00:00:00-05:00
# 49843                   24                  CLKUP 2013-01-01 00:00:00-05:00
# 49844                   24                    NaN 2013-01-01 00:00:00-05:00
# 49845                   21                  CLKUP 2013-01-01 00:00:00-05:00
#
#       remainder__offset   remainder__str_date
# 0                   EST  Jan 01 00:00:00 2013
# 1                   EST  Jan 01 00:00:00 2013
# 2                   EST  Jan 01 00:00:00 2013
# 3                   EST  Jan 01 00:00:00 2013
# 4                   EST  Jan 01 00:00:00 2013
# ...                 ...                   ...
# 49841               EST  Jan 01 00:00:00 2013
# 49842               EST  Jan 01 00:00:00 2013
# 49843               EST  Jan 01 00:00:00 2013
# 49844               EST  Jan 01 00:00:00 2013
# 49845               EST  Jan 01 00:00:00 2013
#
# [49846 rows x 21 columns]

# %% [markdown]
# ## Binning
#
# *Binning* is a process of transforming continuous numerical variables into discrete categorical 'bins'. Binning is used for:
#
# - Converting a continuous feature to a categorical feature
# - Helping with non-linear relationships
# - Reducing the effects of noise and outliers
# - Handling missing values

# %%
# Create a histogram of city08

autos.city08.hist()
# Out:
# <Axes: >

# %%
# use a probability plot to see if it is normally distributed
from scipy import stats
from matplotlib import pyplot as plt

stats.probplot(autos.city08, plot=plt)
# Out:
# ((array([-4.19068501, -3.98490394, -3.8727126 , ...,  3.8727126 ,
#           3.98490394,  4.19068501]),
#   array([  6,   6,   6, ..., 151, 153, 153])),
#  (9.956278912254106, 20.762889700276848, 0.6709866950065863))

# %%
stats.probplot(autos.query('city08 < 40').city08, plot=plt)
# Out:
# ((array([-4.18162241, -3.97541764, -3.86297892, ...,  3.86297892,
#           3.97541764,  4.18162241]),
#   array([ 6,  6,  6, ..., 39, 39, 39])),
#  (4.599703021358444, 18.16130783363955, 0.9783913908420717))

# %%
# bin the city08 data with pandas
pd.cut(autos.city08, bins=10)
# Out:
# 0        (5.853, 20.7]
# 1        (5.853, 20.7]
# 2         (20.7, 35.4]
# 3        (5.853, 20.7]
# 4        (5.853, 20.7]
#              ...
# 49841    (5.853, 20.7]
# 49842    (5.853, 20.7]
# 49843    (5.853, 20.7]
# 49844    (5.853, 20.7]
# 49845    (5.853, 20.7]
# Name: city08, Length: 49846, dtype: category
# Categories (10, interval[float64, right]): [(5.853, 20.7] < (20.7, 35.4] < (35.4, 50.1] < (50.1, 64.8] ... (94.2, 108.9] < (108.9, 123.6] < (123.6, 138.3] < (138.3, 153.0]]

# %%
(pd.cut(autos.city08, bins=10)
 .value_counts()
 .sort_index()
 .plot.bar()
)
# Out:
# <Axes: xlabel='city08'>

# %%
# manually create edges for bins
(pd.cut(autos.city08, bins=[5,10,15,20,40, 140])
 .value_counts()
 .sort_index()
 .plot.bar()
)
# Out:
# <Axes: xlabel='city08'>

# %%
# binning with sklearn
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import KBinsDiscretizer

# Define the binning strategy
binning_strategy = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='quantile')

column_transformer = ColumnTransformer(
    transformers=[
        ('binning', binning_strategy, ['city08'])
    ],
    remainder='passthrough'  # This ensures other columns are left unchanged
)


pipeline = Pipeline(steps=[('transformer', column_transformer)])
pipeline.fit_transform(autos)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_discretization.py:304: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
#        binning__city08  remainder__year remainder__make     remainder__model  \
# 0                  3.0             1985      Alfa Romeo   Spider Veloce 2000
# 1                  0.0             1985         Ferrari           Testarossa
# 2                  4.0             1985           Dodge              Charger
# 3                  0.0             1985           Dodge  B150/B250 Wagon 2WD
# 4                  2.0             1993          Subaru     Legacy AWD Turbo
# ...                ...              ...             ...                  ...
# 49841              3.0             1993          Subaru               Legacy
# 49842              3.0             1993          Subaru               Legacy
# 49843              2.0             1993          Subaru           Legacy AWD
# 49844              2.0             1993          Subaru           Legacy AWD
# 49845              1.0             1993          Subaru     Legacy AWD Turbo
#
#       remainder__trany            remainder__drive remainder__VClass  \
# 0         Manual 5-spd            Rear-Wheel Drive       Two Seaters
# 1         Manual 5-spd            Rear-Wheel Drive       Two Seaters
# 2         Manual 5-spd           Front-Wheel Drive   Subcompact Cars
# 3      Automatic 3-spd            Rear-Wheel Drive              Vans
# 4         Manual 5-spd  4-Wheel or All-Wheel Drive      Compact Cars
# ...                ...                         ...               ...
# 49841  Automatic 4-spd           Front-Wheel Drive      Compact Cars
# 49842     Manual 5-spd           Front-Wheel Drive      Compact Cars
# 49843  Automatic 4-spd  4-Wheel or All-Wheel Drive      Compact Cars
# 49844     Manual 5-spd  4-Wheel or All-Wheel Drive      Compact Cars
# 49845  Automatic 4-spd  4-Wheel or All-Wheel Drive      Compact Cars
#
#       remainder__eng_dscr  remainder__barrels08  remainder__comb08  ...  \
# 0                   (FFS)             14.167143                 21  ...
# 1               (GUZZLER)             27.046364                 11  ...
# 2                   (FFS)             11.018889                 27  ...
# 3                     NaN             27.046364                 11  ...
# 4              (FFS,TRBO)             15.658421                 19  ...
# ...                   ...                   ...                ...  ...
# 49841               (FFS)             13.523182                 22  ...
# 49842               (FFS)             12.935217                 23  ...
# 49843               (FFS)             14.167143                 21  ...
# 49844               (FFS)             14.167143                 21  ...
# 49845          (FFS,TRBO)             16.528333                 18  ...
#
#        remainder__evMotor remainder__cylinders  remainder__displ  \
# 0                     NaN                  4.0               2.0
# 1                     NaN                 12.0               4.9
# 2                     NaN                  4.0               2.2
# 3                     NaN                  8.0               5.2
# 4                     NaN                  4.0               2.2
# ...                   ...                  ...               ...
# 49841                 NaN                  4.0               2.2
# 49842                 NaN                  4.0               2.2
# 49843                 NaN                  4.0               2.2
# 49844                 NaN                  4.0               2.2
# 49845                 NaN                  4.0               2.2
#
#        remainder__fuelCost08  remainder__fuelType remainder__highway08  \
# 0                       2850              Regular                   25
# 1                       5450              Regular                   14
# 2                       2200              Regular                   33
# 3                       5450              Regular                   12
# 4                       3650              Premium                   23
# ...                      ...                  ...                  ...
# 49841                   2700              Regular                   26
# 49842                   2600              Regular                   28
# 49843                   2850              Regular                   24
# 49844                   2850              Regular                   24
# 49845                   3850              Premium                   21
#
#        remainder__trans_dscr      remainder__createdOn remainder__offset  \
# 0                        NaN 2013-01-01 00:00:00-05:00               EST
# 1                        NaN 2013-01-01 00:00:00-05:00               EST
# 2                        SIL 2013-01-01 00:00:00-05:00               EST
# 3                        NaN 2013-01-01 00:00:00-05:00               EST
# 4                        NaN 2013-01-01 00:00:00-05:00               EST
# ...                      ...                       ...               ...
# 49841                  CLKUP 2013-01-01 00:00:00-05:00               EST
# 49842                    NaN 2013-01-01 00:00:00-05:00               EST
# 49843                  CLKUP 2013-01-01 00:00:00-05:00               EST
# 49844                    NaN 2013-01-01 00:00:00-05:00               EST
# 49845                  CLKUP 2013-01-01 00:00:00-05:00               EST
#
#         remainder__str_date
# 0      Jan 01 00:00:00 2013
# 1      Jan 01 00:00:00 2013
# 2      Jan 01 00:00:00 2013
# 3      Jan 01 00:00:00 2013
# 4      Jan 01 00:00:00 2013
# ...                     ...
# 49841  Jan 01 00:00:00 2013
# 49842  Jan 01 00:00:00 2013
# 49843  Jan 01 00:00:00 2013
# 49844  Jan 01 00:00:00 2013
# 49845  Jan 01 00:00:00 2013
#
# [49846 rows x 21 columns]

# %%
pipeline.fit_transform(autos).binning__city08.value_counts().sort_index().plot.bar()
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_discretization.py:304: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# <Axes: xlabel='binning__city08'>

# %%
# pipeline
cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
binning_strategy = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='quantile')

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('binning', binning_strategy, ['city08'])
    ],
    remainder='passthrough'
)

# Create the pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

# Fit and transform the data
pipeline.fit_transform(autos)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_discretization.py:304: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
#        cyl_imputer__cylinders  displ_imputer__displ  binning__city08  \
# 0                         4.0                   2.0              3.0
# 1                        12.0                   4.9              0.0
# 2                         4.0                   2.2              4.0
# 3                         8.0                   5.2              0.0
# 4                         4.0                   2.2              2.0
# ...                       ...                   ...              ...
# 49841                     4.0                   2.2              3.0
# 49842                     4.0                   2.2              3.0
# 49843                     4.0                   2.2              2.0
# 49844                     4.0                   2.2              2.0
# 49845                     4.0                   2.2              1.0
#
#        remainder__year remainder__make     remainder__model remainder__trany  \
# 0                 1985      Alfa Romeo   Spider Veloce 2000     Manual 5-spd
# 1                 1985         Ferrari           Testarossa     Manual 5-spd
# 2                 1985           Dodge              Charger     Manual 5-spd
# 3                 1985           Dodge  B150/B250 Wagon 2WD  Automatic 3-spd
# 4                 1993          Subaru     Legacy AWD Turbo     Manual 5-spd
# ...                ...             ...                  ...              ...
# 49841             1993          Subaru               Legacy  Automatic 4-spd
# 49842             1993          Subaru               Legacy     Manual 5-spd
# 49843             1993          Subaru           Legacy AWD  Automatic 4-spd
# 49844             1993          Subaru           Legacy AWD     Manual 5-spd
# 49845             1993          Subaru     Legacy AWD Turbo  Automatic 4-spd
#
#                  remainder__drive remainder__VClass remainder__eng_dscr  ...  \
# 0                Rear-Wheel Drive       Two Seaters               (FFS)  ...
# 1                Rear-Wheel Drive       Two Seaters           (GUZZLER)  ...
# 2               Front-Wheel Drive   Subcompact Cars               (FFS)  ...
# 3                Rear-Wheel Drive              Vans                 NaN  ...
# 4      4-Wheel or All-Wheel Drive      Compact Cars          (FFS,TRBO)  ...
# ...                           ...               ...                 ...  ...
# 49841           Front-Wheel Drive      Compact Cars               (FFS)  ...
# 49842           Front-Wheel Drive      Compact Cars               (FFS)  ...
# 49843  4-Wheel or All-Wheel Drive      Compact Cars               (FFS)  ...
# 49844  4-Wheel or All-Wheel Drive      Compact Cars               (FFS)  ...
# 49845  4-Wheel or All-Wheel Drive      Compact Cars          (FFS,TRBO)  ...
#
#        remainder__comb08  remainder__range  remainder__evMotor  \
# 0                     21                 0                 NaN
# 1                     11                 0                 NaN
# 2                     27                 0                 NaN
# 3                     11                 0                 NaN
# 4                     19                 0                 NaN
# ...                  ...               ...                 ...
# 49841                 22                 0                 NaN
# 49842                 23                 0                 NaN
# 49843                 21                 0                 NaN
# 49844                 21                 0                 NaN
# 49845                 18                 0                 NaN
#
#       remainder__fuelCost08  remainder__fuelType remainder__highway08  \
# 0                      2850              Regular                   25
# 1                      5450              Regular                   14
# 2                      2200              Regular                   33
# 3                      5450              Regular                   12
# 4                      3650              Premium                   23
# ...                     ...                  ...                  ...
# 49841                  2700              Regular                   26
# 49842                  2600              Regular                   28
# 49843                  2850              Regular                   24
# 49844                  2850              Regular                   24
# 49845                  3850              Premium                   21
#
#        remainder__trans_dscr      remainder__createdOn remainder__offset  \
# 0                        NaN 2013-01-01 00:00:00-05:00               EST
# 1                        NaN 2013-01-01 00:00:00-05:00               EST
# 2                        SIL 2013-01-01 00:00:00-05:00               EST
# 3                        NaN 2013-01-01 00:00:00-05:00               EST
# 4                        NaN 2013-01-01 00:00:00-05:00               EST
# ...                      ...                       ...               ...
# 49841                  CLKUP 2013-01-01 00:00:00-05:00               EST
# 49842                    NaN 2013-01-01 00:00:00-05:00               EST
# 49843                  CLKUP 2013-01-01 00:00:00-05:00               EST
# 49844                    NaN 2013-01-01 00:00:00-05:00               EST
# 49845                  CLKUP 2013-01-01 00:00:00-05:00               EST
#
#         remainder__str_date
# 0      Jan 01 00:00:00 2013
# 1      Jan 01 00:00:00 2013
# 2      Jan 01 00:00:00 2013
# 3      Jan 01 00:00:00 2013
# 4      Jan 01 00:00:00 2013
# ...                     ...
# 49841  Jan 01 00:00:00 2013
# 49842  Jan 01 00:00:00 2013
# 49843  Jan 01 00:00:00 2013
# 49844  Jan 01 00:00:00 2013
# 49845  Jan 01 00:00:00 2013
#
# [49846 rows x 21 columns]

# %%
# replace pyarrow numbers with numpy numbers
cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
binning_strategy = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='quantile')

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('binning', binning_strategy, ['city08'])
    ],
    remainder='passthrough'
)

# Create the pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

# Fit and transform the data
pipeline.fit_transform(autos)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_discretization.py:304: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
#        cyl_imputer__cylinders  displ_imputer__displ  binning__city08  \
# 0                         4.0                   2.0              3.0
# 1                        12.0                   4.9              0.0
# 2                         4.0                   2.2              4.0
# 3                         8.0                   5.2              0.0
# 4                         4.0                   2.2              2.0
# ...                       ...                   ...              ...
# 49841                     4.0                   2.2              3.0
# 49842                     4.0                   2.2              3.0
# 49843                     4.0                   2.2              2.0
# 49844                     4.0                   2.2              2.0
# 49845                     4.0                   2.2              1.0
#
#        remainder__year remainder__make     remainder__model remainder__trany  \
# 0                 1985      Alfa Romeo   Spider Veloce 2000     Manual 5-spd
# 1                 1985         Ferrari           Testarossa     Manual 5-spd
# 2                 1985           Dodge              Charger     Manual 5-spd
# 3                 1985           Dodge  B150/B250 Wagon 2WD  Automatic 3-spd
# 4                 1993          Subaru     Legacy AWD Turbo     Manual 5-spd
# ...                ...             ...                  ...              ...
# 49841             1993          Subaru               Legacy  Automatic 4-spd
# 49842             1993          Subaru               Legacy     Manual 5-spd
# 49843             1993          Subaru           Legacy AWD  Automatic 4-spd
# 49844             1993          Subaru           Legacy AWD     Manual 5-spd
# 49845             1993          Subaru     Legacy AWD Turbo  Automatic 4-spd
#
#                  remainder__drive remainder__VClass remainder__eng_dscr  ...  \
# 0                Rear-Wheel Drive       Two Seaters               (FFS)  ...
# 1                Rear-Wheel Drive       Two Seaters           (GUZZLER)  ...
# 2               Front-Wheel Drive   Subcompact Cars               (FFS)  ...
# 3                Rear-Wheel Drive              Vans                 NaN  ...
# 4      4-Wheel or All-Wheel Drive      Compact Cars          (FFS,TRBO)  ...
# ...                           ...               ...                 ...  ...
# 49841           Front-Wheel Drive      Compact Cars               (FFS)  ...
# 49842           Front-Wheel Drive      Compact Cars               (FFS)  ...
# 49843  4-Wheel or All-Wheel Drive      Compact Cars               (FFS)  ...
# 49844  4-Wheel or All-Wheel Drive      Compact Cars               (FFS)  ...
# 49845  4-Wheel or All-Wheel Drive      Compact Cars          (FFS,TRBO)  ...
#
#        remainder__comb08  remainder__range  remainder__evMotor  \
# 0                     21                 0                 NaN
# 1                     11                 0                 NaN
# 2                     27                 0                 NaN
# 3                     11                 0                 NaN
# 4                     19                 0                 NaN
# ...                  ...               ...                 ...
# 49841                 22                 0                 NaN
# 49842                 23                 0                 NaN
# 49843                 21                 0                 NaN
# 49844                 21                 0                 NaN
# 49845                 18                 0                 NaN
#
#       remainder__fuelCost08  remainder__fuelType remainder__highway08  \
# 0                      2850              Regular                   25
# 1                      5450              Regular                   14
# 2                      2200              Regular                   33
# 3                      5450              Regular                   12
# 4                      3650              Premium                   23
# ...                     ...                  ...                  ...
# 49841                  2700              Regular                   26
# 49842                  2600              Regular                   28
# 49843                  2850              Regular                   24
# 49844                  2850              Regular                   24
# 49845                  3850              Premium                   21
#
#        remainder__trans_dscr      remainder__createdOn remainder__offset  \
# 0                        NaN 2013-01-01 00:00:00-05:00               EST
# 1                        NaN 2013-01-01 00:00:00-05:00               EST
# 2                        SIL 2013-01-01 00:00:00-05:00               EST
# 3                        NaN 2013-01-01 00:00:00-05:00               EST
# 4                        NaN 2013-01-01 00:00:00-05:00               EST
# ...                      ...                       ...               ...
# 49841                  CLKUP 2013-01-01 00:00:00-05:00               EST
# 49842                    NaN 2013-01-01 00:00:00-05:00               EST
# 49843                  CLKUP 2013-01-01 00:00:00-05:00               EST
# 49844                    NaN 2013-01-01 00:00:00-05:00               EST
# 49845                  CLKUP 2013-01-01 00:00:00-05:00               EST
#
#         remainder__str_date
# 0      Jan 01 00:00:00 2013
# 1      Jan 01 00:00:00 2013
# 2      Jan 01 00:00:00 2013
# 3      Jan 01 00:00:00 2013
# 4      Jan 01 00:00:00 2013
# ...                     ...
# 49841  Jan 01 00:00:00 2013
# 49842  Jan 01 00:00:00 2013
# 49843  Jan 01 00:00:00 2013
# 49844  Jan 01 00:00:00 2013
# 49845  Jan 01 00:00:00 2013
#
# [49846 rows x 21 columns]

# %% [markdown]
# ## Log Transform
#
# Log transformation is a data transformation method in which it replaces each variable x with a log(x). This is useful when the data is skewed and you are using a model that assumes normality or linearity.
#
# It is also common to use log transformation on the target variable y in regression.

# %%
# scatter plot to show log of city08 vs original
import numpy as np
(autos
    .assign(city08_log=np.log(autos.city08))
    .plot.scatter(x='city08_log', y='city08')
    )
# Out:
# <Axes: xlabel='city08_log', ylabel='city08'>

# %%
autos.city08.hist()
# Out:
# <Axes: >

# %%
# scatter plot to show log of city08 vs original

(autos
    .assign(city08_log=np.log(autos.city08))
    .city08_log.hist()
    )
# Out:
# <Axes: >

# %%
# Baseline model with linear regression to predict city08
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08']).select_dtypes('number')
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# create pipeline fill cylinders with 0 and displ with median
cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
    ],
    remainder='passthrough'
)

# Use recursive feature elimination to reduce to 5 features
rfe = RFE(estimator=LinearRegression(), n_features_to_select=5)

# pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('rfe', rfe)])

# fit the pipeline
pipeline.fit(X_train, y_train)

# show the 5 selected features
selected_features = X_train.columns[pipeline.named_steps['rfe'].support_]
print('Selected features:', list(selected_features))
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ'])])),
#                 ('lr', LinearRegression())])

# %%
# score
pipeline.score(X_test, y_test)
# Out:
# 0.7811721690912163

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, pipeline.predict(X_test))
# Out:
# 3.994584436067673

# %%
# try again with log transform of y
# create X and y
X = X
y_log = np.log(autos.city08)

# split into train and test
X_train, X_test, y_train_log, y_test_log = train_test_split(X, y_log, random_state=42)

# pipeline
pipeline_log = Pipeline(steps=[('preprocessor', preprocessor), ('lr', LinearRegression())])

# fit the pipeline
pipeline_log.fit(X_train, y_train_log)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ'])])),
#                 ('lr', LinearRegression())])

# %%
pipeline_log.score(X_test, y_test_log)
# Out:
# 0.9081680029292878

# %%
# take exp of predictions and score the mean absolute error
from sklearn.metrics import mean_absolute_error

y_pred_log = np.exp(pipeline_log.predict(X_test))

mean_absolute_error(np.exp(y_test_log), y_pred_log)
# Out:
# 1.9901614485941514

# %% [markdown]
# ## Scaling
#
# *Scaling* is an ambiguous term that generally means one of two things:
#
# -  Min-max scaling - Changing the range of a variable to be between 0 and 1 or -1 to 1.
# -  Standard scaling (Standardization) - Changing the distribution of a variable to have a mean of 0 and a standard deviation of 1.
#
# We'll show examples of both below.

# %%
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08']).select_dtypes('number')
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()

preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
    ],
    remainder='passthrough'
)

pipeline = Pipeline(steps=[('preprocessor', preprocessor), 
                           ('std_scaler', std_scaler),
                           #('minmax_scaler', minmax_scaler), 
                           ('lr', LinearRegression())])

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ'])])),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %% [markdown]
# ## Challenge: Basic Techniques
#
# Predicting mileage from *barrels08*.
#
# - Make a model to predict *city08* from *barrels08* using linear regression.
# - What is the score?
# - Scatter plot *barrel08* vs *city08*
# - Make a new model transforming *barrels08* based on the results of the scatter plot.
# - How does the new model perform?

# %% [markdown]
# ## Solution: Basic Techniques

# %% [markdown]
# # Categorical Encoding

# %% [markdown]
# ## One Hot Encoding
#
# Many ML algorithms cannot work with categorical data directly. The categories must be converted into numbers. This process is called *encoding*.
#
# One of the most common encodings is *one hot encoding*, also called *dummy encoding*. This creates a new column for each category with a 1 or 0 value.

# %%
autos.VClass
# Out:
# 0            Two Seaters
# 1            Two Seaters
# 2        Subcompact Cars
# 3                   Vans
# 4           Compact Cars
#               ...
# 49841       Compact Cars
# 49842       Compact Cars
# 49843       Compact Cars
# 49844       Compact Cars
# 49845       Compact Cars
# Name: VClass, Length: 49846, dtype: object

# %%
pd.get_dummies(autos.VClass)
# Out:
#        Compact Cars  Large Cars  Midsize Cars  Midsize Station Wagons  \
# 0             False       False         False                   False
# 1             False       False         False                   False
# 2             False       False         False                   False
# 3             False       False         False                   False
# 4              True       False         False                   False
# ...             ...         ...           ...                     ...
# 49841          True       False         False                   False
# 49842          True       False         False                   False
# 49843          True       False         False                   False
# 49844          True       False         False                   False
# 49845          True       False         False                   False
#
#        Midsize-Large Station Wagons  Minicompact Cars  Minivan - 2WD  \
# 0                             False             False          False
# 1                             False             False          False
# 2                             False             False          False
# 3                             False             False          False
# 4                             False             False          False
# ...                             ...               ...            ...
# 49841                         False             False          False
# 49842                         False             False          False
# 49843                         False             False          False
# 49844                         False             False          False
# 49845                         False             False          False
#
#        Minivan - 4WD  Small Pickup Trucks  Small Pickup Trucks 2WD  ...  \
# 0              False                False                    False  ...
# 1              False                False                    False  ...
# 2              False                False                    False  ...
# 3              False                False                    False  ...
# 4              False                False                    False  ...
# ...              ...                  ...                      ...  ...
# 49841          False                False                    False  ...
# 49842          False                False                    False  ...
# 49843          False                False                    False  ...
# 49844          False                False                    False  ...
# 49845          False                False                    False  ...
#
#        Standard Pickup Trucks 4WD  Standard Pickup Trucks/2wd  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 49841                       False                       False
# 49842                       False                       False
# 49843                       False                       False
# 49844                       False                       False
# 49845                       False                       False
#
#        Standard Sport Utility Vehicle 2WD  Standard Sport Utility Vehicle 4WD  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
# 3                                   False                               False
# 4                                   False                               False
# ...                                   ...                                 ...
# 49841                               False                               False
# 49842                               False                               False
# 49843                               False                               False
# 49844                               False                               False
# 49845                               False                               False
#
#        Subcompact Cars  Two Seaters   Vans  Vans Passenger  Vans, Cargo Type  \
# 0                False         True  False           False             False
# 1                False         True  False           False             False
# 2                 True        False  False           False             False
# 3                False        False   True           False             False
# 4                False        False  False           False             False
# ...                ...          ...    ...             ...               ...
# 49841            False        False  False           False             False
# 49842            False        False  False           False             False
# 49843            False        False  False           False             False
# 49844            False        False  False           False             False
# 49845            False        False  False           False             False
#
#        Vans, Passenger Type
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 49841                 False
# 49842                 False
# 49843                 False
# 49844                 False
# 49845                 False
#
# [49846 rows x 34 columns]

# %%
pd.get_dummies(autos.VClass, drop_first=True)
# Out:
#        Large Cars  Midsize Cars  Midsize Station Wagons  \
# 0           False         False                   False
# 1           False         False                   False
# 2           False         False                   False
# 3           False         False                   False
# 4           False         False                   False
# ...           ...           ...                     ...
# 49841       False         False                   False
# 49842       False         False                   False
# 49843       False         False                   False
# 49844       False         False                   False
# 49845       False         False                   False
#
#        Midsize-Large Station Wagons  Minicompact Cars  Minivan - 2WD  \
# 0                             False             False          False
# 1                             False             False          False
# 2                             False             False          False
# 3                             False             False          False
# 4                             False             False          False
# ...                             ...               ...            ...
# 49841                         False             False          False
# 49842                         False             False          False
# 49843                         False             False          False
# 49844                         False             False          False
# 49845                         False             False          False
#
#        Minivan - 4WD  Small Pickup Trucks  Small Pickup Trucks 2WD  \
# 0              False                False                    False
# 1              False                False                    False
# 2              False                False                    False
# 3              False                False                    False
# 4              False                False                    False
# ...              ...                  ...                      ...
# 49841          False                False                    False
# 49842          False                False                    False
# 49843          False                False                    False
# 49844          False                False                    False
# 49845          False                False                    False
#
#        Small Pickup Trucks 4WD  ...  Standard Pickup Trucks 4WD  \
# 0                        False  ...                       False
# 1                        False  ...                       False
# 2                        False  ...                       False
# 3                        False  ...                       False
# 4                        False  ...                       False
# ...                        ...  ...                         ...
# 49841                    False  ...                       False
# 49842                    False  ...                       False
# 49843                    False  ...                       False
# 49844                    False  ...                       False
# 49845                    False  ...                       False
#
#        Standard Pickup Trucks/2wd  Standard Sport Utility Vehicle 2WD  \
# 0                           False                               False
# 1                           False                               False
# 2                           False                               False
# 3                           False                               False
# 4                           False                               False
# ...                           ...                                 ...
# 49841                       False                               False
# 49842                       False                               False
# 49843                       False                               False
# 49844                       False                               False
# 49845                       False                               False
#
#        Standard Sport Utility Vehicle 4WD  Subcompact Cars  Two Seaters  \
# 0                                   False            False         True
# 1                                   False            False         True
# 2                                   False             True        False
# 3                                   False            False        False
# 4                                   False            False        False
# ...                                   ...              ...          ...
# 49841                               False            False        False
# 49842                               False            False        False
# 49843                               False            False        False
# 49844                               False            False        False
# 49845                               False            False        False
#
#         Vans  Vans Passenger  Vans, Cargo Type  Vans, Passenger Type
# 0      False           False             False                 False
# 1      False           False             False                 False
# 2      False           False             False                 False
# 3       True           False             False                 False
# 4      False           False             False                 False
# ...      ...             ...               ...                   ...
# 49841  False           False             False                 False
# 49842  False           False             False                 False
# 49843  False           False             False                 False
# 49844  False           False             False                 False
# 49845  False           False             False                 False
#
# [49846 rows x 33 columns]

# %%
# Cardinality - number of unique values in a column
# probably don't want to make ~5k model columns
(autos
 .select_dtypes(object) # use 'string[pyarrow]' if using pyarrow types
 .nunique()
)
# Out:
# make           146
# model         5560
# trany           40
# drive            7
# VClass          34
# eng_dscr       626
# evMotor        593
# fuelType        16
# trans_dscr      52
# offset           2
# str_date       473
# dtype: int64

# %%
# Cardinality - number of unique values in a column
# probably don't want to make ~5k model columns
(autos
 .select_dtypes(object)
 .nunique()
 .index
)
# Out:
# Index(['make', 'model', 'trany', 'drive', 'VClass', 'eng_dscr', 'evMotor',
#        'fuelType', 'trans_dscr', 'offset', 'str_date'],
#       dtype='object')

# %%
# categorical encoding in pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder

X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False)

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),

        ('one_hot_encoder', one_hot_encoder, ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ],),
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor), 
                          ('std_scaler', std_scaler),
                           #  ('minmax_scaler', minmax_scaler, ['range']),
                           ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ']),
#                                                  ('one_hot_encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 max_categories=10,
#                                                                 sparse_output=False),
#                                                   ['make', 'model', 'trany',
#                                                    'drive', 'VClass',
#                                                    'eng_dscr', 'evMotor',
#                                                    'fuelType',
#                                                    'trans_dscr'])])),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
# Impute missing values AND convert Pandas 2 strings to Pandas 1 strings
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder

X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False)

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('cat_imputer', cat_imputer, cat_cols),
        ('one_hot_encoder', one_hot_encoder, cat_cols),
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor), 
                          ('std_scaler', std_scaler),
                           #  ('minmax_scaler', minmax_scaler, ['range']),
                           ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train.assign(**X_train.select_dtypes('string[pyarrow]').astype(str)), y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3681/1428735610.py in ?()
#      35                            #  ('minmax_scaler', minmax_scaler, ['range']),
#      36                            ('lr', LinearRegression())])
#      37
#      38 # fit the pipeline
# ---> 39 pipeline.fit(X_train.assign(**X_train.select_dtypes('string[pyarrow]').astype(str)), y_train)
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/pipeline.py in ?(self, X, y, **params)
#     609                 "`sklearn.set_config(enable_metadata_routing=True)`."
#     610             )
#     611
#     612         routed_params = self._check_method_params(method="fit", props=params)
# --> 613         Xt = self._fit(X, y, routed_params, raw_params=params)
#     614         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     615             if self._final_estimator != "passthrough":
#     616                 last_step_params = self._get_metadata_for_step(
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/pipeline.py in ?(self, X, y, routed_params, raw_params)
#     543                 step_params=routed_params[name],
#     544                 all_params=raw_params,
#     545             )
#     546
# --> 547             X, fitted_transformer = fit_transform_one_cached(
#     548                 cloned_transformer,
#     549                 X,
#     550                 y,
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/joblib/memory.py in ?(self, *args, **kwargs)
#     325     def __call__(self, *args, **kwargs):
# --> 326         return self.func(*args, **kwargs)
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/pipeline.py in ?(transformer, X, y, weight, message_clsname, message, params)
#    1480     """
#    1481     params = params or {}
#    1482     with _print_elapsed_time(message_clsname, message):
#    1483         if hasattr(transformer, "fit_transform"):
# -> 1484             res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1485         else:
#    1486             res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1487                 X, **params.get("transform", {})
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/base.py in ?(self, X, y, **fit_params)
#     906             # fit method of arity 1 (unsupervised transformation)
#     907             return self.fit(X, **fit_params).transform(X)
#     908         else:
#     909             # fit method of arity 2 (supervised transformation)
# --> 910             return self.fit(X, y, **fit_params).transform(X)
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     920             Fitted scaler.
#     921         """
#     922         # Reset internal state before fitting
#     923         self._reset()
# --> 924         return self.partial_fit(X, y, sample_weight)
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     957             Fitted scaler.
#     958         """
#     959         xp, _, X_device = get_namespace_and_device(X)
#     960         first_call = not hasattr(self, "n_samples_seen_")
# --> 961         X = validate_data(
#     962             self,
#     963             X,
#     964             accept_sparse=("csr", "csc"),
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2898             out = y
#    2899         else:
#    2900             out = X, y
#    2901     elif not no_val_X and no_val_y:
# -> 2902         out = check_array(X, input_name="X", **check_params)
#    2903     elif no_val_X and not no_val_y:
#    2904         out = _check_y(y, **check_params)
#    2905     else:
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1019                         )
#    1020                     array = xp.astype(array, dtype, copy=False)
#    1021                 else:
#    1022                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1023             except ComplexWarning as complex_warning:
#    1024                 raise ValueError(
#    1025                     "Complex data not supported\n{}\n".format(array)
#    1026                 ) from complex_warning
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     874         # Use NumPy API to support order
#     875         if copy is True:
#     876             array = numpy.array(array, order=order, dtype=dtype)
#     877         else:
# --> 878             array = numpy.asarray(array, order=order, dtype=dtype)
#     879
#     880         # At this point array is a NumPy ndarray. We convert it to an array
#     881         # container that is consistent with the input's namespace.
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, dtype)
#    2148     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2149         values = self._values
# -> 2150         arr = np.asarray(values, dtype=dtype)
#    2151         if (
#    2152             astype_is_view(values.dtype, arr.dtype)
#    2153             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Ferrari'

# %%
# Debug with FunctionTransformer
# And figure out that I need a separate pipeline for categorical columns
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder

X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False)

def debug_transformer(X, name):
    globals()[name] = X
    return X

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]

cat_pipe = Pipeline([
    ('cat_imputer', cat_imputer),
    ('one_hot_encoder', one_hot_encoder)
])

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('cat_pl', cat_pipe, cat_cols),
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor), 
                           ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),
                           ('std_scaler', std_scaler),
                           #  ('minmax_scaler', minmax_scaler, ['range']),
                           ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ']),
#                                                  ('cat_pl',
#                                                   Pipeline(steps=[('cat_imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('one_hot_encoder',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  max_categories=10,
#                                                                                  sparse_output=False))]),
#                                                   ['make', 'model', 'trany',
#                                                    'drive', 'VClass',
#                                                    'eng_dscr', 'evMotor',
#                                                    'fuelType',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cece143880>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
tmp_X
# Out:
#        cyl_imputer__cylinders  displ_imputer__displ  cat_pl__make_Chevrolet  \
# 44707                     8.0                   3.4                     0.0
# 27296                     4.0                   1.6                     0.0
# 13095                     6.0                   3.1                     0.0
# 48291                     4.0                   1.6                     0.0
# 11146                     4.0                   1.9                     0.0
# ...                       ...                   ...                     ...
# 11284                     8.0                   5.3                     1.0
# 44732                     4.0                   1.5                     0.0
# 38158                     8.0                   5.3                     1.0
# 860                       6.0                   2.5                     0.0
# 15795                     4.0                   2.4                     1.0
#
#        cat_pl__make_Dodge  cat_pl__make_Ford  cat_pl__make_GMC  \
# 44707                 0.0                0.0               0.0
# 27296                 0.0                0.0               0.0
# 13095                 0.0                0.0               0.0
# 48291                 0.0                0.0               0.0
# 11146                 0.0                0.0               0.0
# ...                   ...                ...               ...
# 11284                 0.0                0.0               0.0
# 44732                 0.0                0.0               0.0
# 38158                 0.0                0.0               0.0
# 860                   0.0                0.0               0.0
# 15795                 0.0                0.0               0.0
#
#        cat_pl__make_Mercedes-Benz  cat_pl__make_Nissan  cat_pl__make_Porsche  \
# 44707                         0.0                  0.0                   0.0
# 27296                         0.0                  0.0                   0.0
# 13095                         0.0                  0.0                   0.0
# 48291                         0.0                  1.0                   0.0
# 11146                         0.0                  0.0                   0.0
# ...                           ...                  ...                   ...
# 11284                         0.0                  0.0                   0.0
# 44732                         0.0                  0.0                   0.0
# 38158                         0.0                  0.0                   0.0
# 860                           0.0                  0.0                   0.0
# 15795                         0.0                  0.0                   0.0
#
#        cat_pl__make_Toyota  ...  cat_pl__trans_dscr_CLKUP  \
# 44707                  0.0  ...                       0.0
# 27296                  0.0  ...                       0.0
# 13095                  0.0  ...                       0.0
# 48291                  0.0  ...                       0.0
# 11146                  0.0  ...                       0.0
# ...                    ...  ...                       ...
# 11284                  0.0  ...                       1.0
# 44732                  0.0  ...                       1.0
# 38158                  0.0  ...                       0.0
# 860                    0.0  ...                       1.0
# 15795                  0.0  ...                       1.0
#
#        cat_pl__trans_dscr_Creeper  cat_pl__trans_dscr_EMS 2MODE CLKUP  \
# 44707                         0.0                                 0.0
# 27296                         0.0                                 0.0
# 13095                         0.0                                 0.0
# 48291                         0.0                                 0.0
# 11146                         0.0                                 0.0
# ...                           ...                                 ...
# 11284                         0.0                                 0.0
# 44732                         0.0                                 0.0
# 38158                         0.0                                 0.0
# 860                           0.0                                 0.0
# 15795                         0.0                                 0.0
#
#        cat_pl__trans_dscr_SIL  cat_pl__trans_dscr_missing  \
# 44707                     0.0                         1.0
# 27296                     0.0                         1.0
# 13095                     0.0                         1.0
# 48291                     0.0                         1.0
# 11146                     1.0                         0.0
# ...                       ...                         ...
# 11284                     0.0                         0.0
# 44732                     0.0                         0.0
# 38158                     0.0                         1.0
# 860                       0.0                         0.0
# 15795                     0.0                         0.0
#
#        cat_pl__trans_dscr_infrequent_sklearn  remainder__year  \
# 44707                                    0.0             1989
# 27296                                    0.0             2015
# 13095                                    0.0             2006
# 48291                                    0.0             1985
# 11146                                    0.0             1986
# ...                                      ...              ...
# 11284                                    0.0             2004
# 44732                                    0.0             1989
# 38158                                    0.0             2022
# 860                                      0.0             1994
# 15795                                    0.0             2008
#
#        remainder__barrels08  remainder__range  remainder__fuelCost08
# 44707             22.885385                 0                   5300
# 27296             10.258966                 0                   2400
# 13095             15.658421                 0                   3650
# 48291             11.900400                 0                   2400
# 11146             12.396250                 0                   2500
# ...                     ...               ...                    ...
# 11284             19.834000                 0                   4000
# 44732             11.442692                 0                   2300
# 38158             16.528333                 0                   3300
# 860               14.875500                 0                   3450
# 15795             11.018889                 0                   2200
#
# [37384 rows x 85 columns]

# %%
pipeline.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pipeline.score(X_test, y_test)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/pipeline.py:1131, in Pipeline.score(self, X, y, sample_weight, **params)
#    1129 if not _routing_enabled():
#    1130     for _, name, transform in self._iter(with_final=False):
# -> 1131         Xt = transform.transform(Xt)
#    1132     score_params = {}
#    1133     if sample_weight is not None:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:1099, in ColumnTransformer.transform(self, X, **params)
#    1096 else:
#    1097     routed_params = self._get_empty_routing()
# -> 1099 Xs = self._call_func_on_transformers(
#    1100     X,
#    1101     None,
#    1102     _transform_one,
#    1103     column_as_labels=fit_dataframe_and_transform_dataframe,
#    1104     routed_params=routed_params,
#    1105 )
#    1106 self._validate_output(Xs)
#    1108 if not Xs:
#    1109     # All transformers are None
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:901, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     889             extra_args = {}
#     890         jobs.append(
#     891             delayed(func)(
#     892                 transformer=clone(trans) if not fitted else trans,
#    (...)    898             )
#     899         )
# --> 901     return Parallel(n_jobs=self.n_jobs)(jobs)
#     903 except ValueError as e:
#     904     if "Expected 2D array, got 1D array instead" in str(e):
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/pipeline.py:1464, in _transform_one(transformer, X, y, weight, params)
#    1442 def _transform_one(transformer, X, y, weight, params):
#    1443     """Call transform and apply weight to output.
#    1444
#    1445     Parameters
#    (...)   1462         This should be of the form ``process_routing()["step_name"]``.
#    1463     """
# -> 1464     res = transformer.transform(X, **params.transform)
#    1465     # if we have a weight for this transformer, multiply output
#    1466     if weight is None:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/pipeline.py:1043, in Pipeline.transform(self, X, **params)
#    1041 Xt = X
#    1042 for _, name, transform in self._iter():
# -> 1043     Xt = transform.transform(Xt, **routed_params[name].transform)
#    1044 return Xt
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:1051, in OneHotEncoder.transform(self, X)
#    1046     warn_on_unknown = self.drop is not None and self.handle_unknown in {
#    1047         "ignore",
#    1048         "infrequent_if_exist",
#    1049     }
#    1050     handle_unknown = self.handle_unknown
# -> 1051 X_int, X_mask = self._transform(
#    1052     X,
#    1053     handle_unknown=handle_unknown,
#    1054     ensure_all_finite="allow-nan",
#    1055     warn_on_unknown=warn_on_unknown,
#    1056 )
#    1058 n_samples, n_features = X_int.shape
#    1060 if self._drop_idx_after_grouping is not None:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:220, in _BaseEncoder._transform(self, X, handle_unknown, ensure_all_finite, warn_on_unknown, ignore_category_indices)
#     215 if handle_unknown == "error":
#     216     msg = (
#     217         "Found unknown categories {0} in column {1}"
#     218         " during transform".format(diff, i)
#     219     )
# --> 220     raise ValueError(msg)
#     221 else:
#     222     if warn_on_unknown:
#
# ValueError: Found unknown categories ['Kandi', 'S and S Coach Company  E.p. Dutton', 'Qvale', 'Evans Automobiles', 'Environmental Rsch and Devp Corp', 'Laforza Automobile Inc', 'Azure Dynamics', 'Mini'] in column 0 during transform

# %%
# Deal with missing categories in test set w/ handle_unknown='ignore'
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder

X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Add handle_unknown='ignore' to OneHotEncoder
# one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False)
cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')

def debug_transformer(X, name):
    globals()[name] = X
    return X

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]

cat_pipe = Pipeline([
    ('cat_imputer', cat_imputer),
    ('one_hot_encoder', one_hot_encoder)
])

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('cat_pl', cat_pipe, cat_cols),
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor), 
                           ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),
                          ('std_scaler', std_scaler),
                           #  ('minmax_scaler', minmax_scaler, ['range']),
                           ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ']),
#                                                  ('cat_pl',
#                                                   Pipeline(steps=[('cat_imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('one_hot_encoder',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  max_categories=10,
#                                                                                  sparse_output=False))]),
#                                                   ['make', 'model', 'trany',
#                                                    'drive', 'VClass',
#                                                    'eng_dscr', 'evMotor',
#                                                    'fuelType',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cecd38dda0>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
pipeline.score(X_test, y_test)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:261: UserWarning: Found unknown categories in columns [0, 1, 5, 6, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(msg, UserWarning)
# 0.9297485083408437

# %% [markdown]
# ## Hash Encoding
#
# *Hash encoding* is a technique that can be used when there are too many categories to encode with one hot encoding. It is similar to one hot encoding, but the categories are hashed into a smaller number of columns.
#
# We are going to use the `category_encoders` library to do the encoding. This library has many other encoders that you can explore.

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.9.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from category_encoders) (2.2.0)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from category_encoders) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from category_encoders) (1.17.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from category_encoders) (0.14.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels>=0.9.0->category_encoders) (26.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
(autos
 .select_dtypes(object)
 .nunique()
)
# Out:
# make           146
# model         5560
# trany           40
# drive            7
# VClass          34
# eng_dscr       626
# evMotor        593
# fuelType        16
# trans_dscr      52
# offset           2
# str_date       473
# dtype: int64

# %%
(autos
 .select_dtypes(object)
 .nunique()
 .pipe(lambda s: s[s > 40])
 .index
)
# Out:
# Index(['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr', 'str_date'], dtype='object')

# %%
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']

# %%
# low cardinality columns
(autos
 .select_dtypes(object)
 .nunique()
 .index
 .difference(high_cardinality_cols)
)
# Out:
# Index(['VClass', 'drive', 'fuelType', 'offset', 'str_date', 'trany'], dtype='object')

# %%
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']

# %%
# replace one hot encoder with hashing encoder for high cardinality columns
from category_encoders import hashing
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder

X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# add hashing encoder
cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')
hashing_encoder = hashing.HashingEncoder(n_components=10, drop_invariant=True)

def debug_transformer(X, name):
    globals()[name] = X
    return X

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']


# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        #('cat_pl', cat_pipe, cat_cols),
        ('one_hot_encoder', one_hot_encoder, low_cardinality_cols),
        ('hashing_encoder', hashing_encoder, high_cardinality_cols)
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor), 
                           ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),
                          ('std_scaler', std_scaler),
                           #  ('minmax_scaler', minmax_scaler, ['range']),
                           ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/externals/_numpydoc/docscrape.py:420: UserWarning: Unknown section Example
#   self[section] = content
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ']),
#                                                  ('one_hot_encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 max_categories=10,
#                                                                 sparse_output=False),
#                                                   ['VClass', 'drive',
#                                                    'fuelType', 'trany']),
#                                                  ('hashing_encoder',
#                                                   HashingEncoder(drop_invariant=True,
#                                                                  max_process=1,
#                                                                  n_components=10),
#                                                   ['make', 'model', 'eng_dscr',
#                                                    'evMotor',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cecd38d620>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %% [markdown]
# # Target Encoding
#
# From docstring: [In Target Encoding] Each category is encoded based on a shrunk estimate of the average target
# values for observations belonging to the category. The encoding scheme mixes
# the global target mean with the target mean conditioned on the value of the
# category.

# %%
from sklearn.preprocessing import TargetEncoder

te = TargetEncoder(target_type='continuous', random_state=42)
te.fit_transform(X_train[['make']], y_train)
# Out:
#             make
# 44707  11.909361
# 27296  26.544816
# 13095  22.582320
# 48291  21.895705
# 11146  18.737618
# ...          ...
# 11284  17.684576
# 44732  29.184924
# 38158  17.695542
# 860    20.829680
# 15795  17.684576
#
# [37384 rows x 1 columns]

# %%
# replace hashing encoder with target encoder for high cardinality columns
from category_encoders import hashing
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder, TargetEncoder

# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# create pipeline fill cylinders with 0 and displ with median
cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')
hashing_encoder = hashing.HashingEncoder(n_components=10, drop_invariant=True)
target_encoder = TargetEncoder(target_type='continuous', random_state=42)

def debug_transformer(X, name):
    globals()[name] = X
    return X

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('one_hot_encoder', one_hot_encoder, low_cardinality_cols),
        #('hashing_encoder', hashing_encoder, high_cardinality_cols)
        ('target_encoder', target_encoder, high_cardinality_cols)
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor), 
                           ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),
                          ('std_scaler', std_scaler),
                           #  ('minmax_scaler', minmax_scaler, ['range']),
                           ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ']),
#                                                  ('one_hot_encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 max_categories=10,
#                                                                 sparse_output=False),
#                                                   ['VClass', 'drive',
#                                                    'fuelType', 'trany']),
#                                                  ('target_encoder',
#                                                   TargetEncoder(random_state=42,
#                                                                 target_type='continuous'),
#                                                   ['make', 'model', 'eng_dscr',
#                                                    'evMotor',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cece1ca660>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
X = autos[['barrels08']]
y = autos['city08']

# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

pipeline = Pipeline(steps=[('lr', LinearRegression())])

pipeline.fit(X_train, y_train)
pipeline.score(X_test, y_test)
# Out:
# 0.5572188037234922

# %%
pipeline.score(X_test.assign(**X_test.select_dtypes('string[pyarrow]').astype(str)),
                y_test)
# Out:
# 0.5572188037234922

# %%
# make a custom class transformer to remove PyArrow strings (if using PyArrow)
from sklearn.base import BaseEstimator, TransformerMixin

class PyArrowStringConverter(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        return X.assign(**X.select_dtypes('string[pyarrow]').astype(str))

# %%
# replace hashing encoder with target encoder for high cardinality columns

from category_encoders import hashing
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder, TargetEncoder


# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# create pipeline fill cylinders with 0 and displ with median

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')
hashing_encoder = hashing.HashingEncoder(n_components=10, drop_invariant=True)
target_encoder = TargetEncoder(target_type='continuous', random_state=42)

def debug_transformer(X, name):
    globals()[name] = X
    return X

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']


# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('one_hot_encoder', one_hot_encoder, low_cardinality_cols),
        #('hashing_encoder', hashing_encoder, high_cardinality_cols)
        ('target_encoder', target_encoder, high_cardinality_cols)
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[
    ('string_converter', PyArrowStringConverter()),
    ('preprocessor', preprocessor), 
    ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),
    ('std_scaler', std_scaler),
    #  ('minmax_scaler', minmax_scaler, ['range']),
    ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('string_converter', PyArrowStringConverter()),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ']),
#                                                  ('one_hot_encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 max_cat...
#                                                                 sparse_output=False),
#                                                   ['VClass', 'drive',
#                                                    'fuelType', 'trany']),
#                                                  ('target_encoder',
#                                                   TargetEncoder(random_state=42,
#                                                                 target_type='continuous'),
#                                                   ['make', 'model', 'eng_dscr',
#                                                    'evMotor',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cecd38c0e0>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
pipeline.score(X_test, y_test)
# Out:
# 0.9482896171075316

# %% [markdown]
# ## Categorical Challenge
#
# Create a model to predict mileage using only the categorical columns (dropping the *model* column)
#
# ```
# cat_cols = ['trany', 'drive', 'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr']
# ```

# %% [markdown]
# ## Solution: Categorical Challenge

# %%
# Create features using only categorical columns
cat_cols = ['trany', 'drive', 'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr']

# Prepare X and y
y = autos.city08
X = autos[cat_cols]

# Split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a pipeline for categorical encoding
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# Create categorical pipeline
cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# Create full pipeline with preprocessing and model
full_pipeline = Pipeline([
    ('preprocessor', ColumnTransformer([
        ('cat', cat_pipeline, cat_cols)
    ])),
    ('model', LinearRegression())
])

# Fit the model
full_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['trany', 'drive', 'VClass',
#                                                    'eng_dscr', 'evMotor',
#                                                    'fuelType',
#                                                    'trans_dscr'])])),
#                 ('model', LinearRegression())])

# %%
# Evaluate the model
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Make predictions
y_train_pred = full_pipeline.predict(X_train)
y_test_pred = full_pipeline.predict(X_test)

# Calculate metrics
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)
train_rmse = np.sqrt(train_mse)
test_rmse = np.sqrt(test_mse)
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

print(f"Train RMSE: {train_rmse:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Train R²: {train_r2:.4f}")
print(f"Test R²: {test_r2:.4f}")
# Out:
# Train RMSE: 2.8818
# Test RMSE: 3.3713
# Train R²: 0.9623
# Test R²: 0.9482

# %%
# Visualize model predictions
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Plot 1: Actual vs Predicted (Test Set)
axes[0].scatter(y_test, y_test_pred, alpha=0.5)
axes[0].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0].set_xlabel('Actual MPG')
axes[0].set_ylabel('Predicted MPG')
axes[0].set_title(f'Test Set (R² = {test_r2:.4f})')
axes[0].grid(True, alpha=0.3)

# Plot 2: Residuals (Test Set)
residuals = y_test - y_test_pred
axes[1].scatter(y_test_pred, residuals, alpha=0.5)
axes[1].axhline(y=0, color='r', linestyle='--', lw=2)
axes[1].set_xlabel('Predicted MPG')
axes[1].set_ylabel('Residuals')
axes[1].set_title('Residuals Plot')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Get feature names and coefficients
preprocessor = full_pipeline.named_steps['preprocessor']
feature_names = preprocessor.get_feature_names_out()
model = full_pipeline.named_steps['model']
coefficients = model.coef_

# Create a dataframe of features and their coefficients
feature_importance = pd.DataFrame({
    'feature': feature_names,
    'coefficient': coefficients
}).sort_values('coefficient', key=abs, ascending=False)

print("Top 10 Most Important Features:")
print(feature_importance.head(10))
# Out:
# Top 10 Most Important Features:
#                                                 feature  coefficient
# 1200                          cat__fuelType_Electricity    92.494882
# 1091                     cat__evMotor_56kW AC Induction   -70.079540
# 1082                     cat__evMotor_49kW DC Brushless   -60.827683
# 1079                    cat__evMotor_49 kW DC Brushless   -60.827683
# 956            cat__evMotor_226 and 550 kW AC Induction   -57.099105
# 955            cat__evMotor_226 and 500 kW AC Induction   -57.099105
# 1164                    cat__evMotor_85 kW AC Induction   -55.296263
# 958   cat__evMotor_226, 226, 450 and 450 kW AC Induc...   -55.099105
# 957                    cat__evMotor_226 kW AC Induction   -55.099105
# 1106                    cat__evMotor_67 KW AC Induction   -55.011177

# %%
# Visualize feature importance
plt.figure(figsize=(10, 6))
top_features = feature_importance.head(15)
plt.barh(range(len(top_features)), top_features['coefficient'])
plt.yticks(range(len(top_features)), top_features['feature'])
plt.xlabel('Coefficient Value')
plt.title('Top 15 Feature Coefficients')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Summary of the categorical model
print("=" * 60)
print("CATEGORICAL FEATURES MODEL SUMMARY")
print("=" * 60)
print(f"\nFeatures used: {cat_cols}")
print(f"\nNumber of samples:")
print(f"  Training: {len(X_train)}")
print(f"  Testing: {len(X_test)}")
print(f"\nModel Performance:")
print(f"  Train RMSE: {train_rmse:.4f} MPG")
print(f"  Test RMSE: {test_rmse:.4f} MPG")
print(f"  Train R²: {train_r2:.4f}")
print(f"  Test R²: {test_r2:.4f}")
print(f"\nModel Type: Linear Regression with One-Hot Encoding")
print(f"Total number of features after encoding: {len(feature_names)}")
print("=" * 60)
# Out:
# ============================================================
# CATEGORICAL FEATURES MODEL SUMMARY
# ============================================================
#
# Features used: ['trany', 'drive', 'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr']
#
# Number of samples:
#   Training: 37384
#   Testing: 12462
#
# Model Performance:
#   Train RMSE: 2.8818 MPG
#   Test RMSE: 3.3713 MPG
#   Train R²: 0.9623
#   Test R²: 0.9482
#
# Model Type: Linear Regression with One-Hot Encoding
# Total number of features after encoding: 1266
# ============================================================

# %% [markdown]
# # Feature Extraction
#
# Feature extraction is the process of transforming raw data into features that better represent the underlying problem to the predictive models, resulting in improved model accuracy on unseen data.

# %% [markdown]
# ## PCA
#
# *Principal Component Analysis* (PCA) is a technique for reducing the dimensionality of data. It can also remove noise and might be useful as feature engineering for other algorithms. See my ML algorigthms course for more details.

# %%
# Create PCA Pipeline
from sklearn.decomposition import PCA

# replace hashing encoder with target encoder for high cardinality columns
# import pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from category_encoders import hashing
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder, TargetEncoder
from sklearn import set_config
set_config(transform_output='pandas')

# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# create pipeline fill cylinders with 0 and displ with median

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')
hashing_encoder = hashing.HashingEncoder(n_components=10, drop_invariant=True)
target_encoder = TargetEncoder(target_type='continuous', random_state=42)

def debug_transformer(X, name):
    globals()[name] = X
    return X

class PyArrowStringConverter(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        return X.assign(**X.select_dtypes('string[pyarrow]').astype(str))

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']


# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('one_hot_encoder', one_hot_encoder, low_cardinality_cols),
        #('hashing_encoder', hashing_encoder, high_cardinality_cols)
        ('target_encoder', target_encoder, high_cardinality_cols)
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[
    ('string_converter', PyArrowStringConverter()),
    ('preprocessor', preprocessor), 
    ('std_scaler', std_scaler),
    ('pca', PCA(n_components=10)),
    ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),    
    #  ('minmax_scaler', minmax_scaler, ['range']),
    ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('string_converter', PyArrowStringConverter()),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ']),
#                                                  ('one_hot_encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 max_cat...
#                                                   ['VClass', 'drive',
#                                                    'fuelType', 'trany']),
#                                                  ('target_encoder',
#                                                   TargetEncoder(random_state=42,
#                                                                 target_type='continuous'),
#                                                   ['make', 'model', 'eng_dscr',
#                                                    'evMotor',
#                                                    'trans_dscr'])])),
#                 ('std_scaler', StandardScaler()), ('pca', PCA(n_components=10)),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cecd38ee80>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('lr', LinearRegression())])

# %%
pipeline.score(X_test, y_test)
# Out:
# 0.9158389032991753

# %%
# Pros - Noise removed, less columns
# Cons - Less explainable
tmp_X
# Out:
#            pca0      pca1      pca2      pca3      pca4      pca5      pca6  \
# 46169  0.289315  2.699108 -0.425897 -0.152921  0.816223 -1.470038  0.305614
# 38354 -1.063877 -1.463219 -0.661536 -3.368533  1.044867 -1.003517 -0.753907
# 25598 -8.633770  0.759856  3.927157  1.887289 -0.742831 -1.161714 -0.737920
# 5235   3.666349 -0.924937  2.839649 -0.550288 -0.719635  1.145082  0.132804
# 10009  0.880115  0.947763  0.996918 -0.774829 -2.238041  0.690275  0.012056
# ...         ...       ...       ...       ...       ...       ...       ...
# 32846 -1.621580  1.033346 -0.585609 -1.360209 -1.393015 -0.957710 -0.388729
# 35648 -2.134812  1.048779 -2.050952 -0.907007  0.211317  0.379948  1.245680
# 6527   1.073866 -0.818976  0.473516  0.365712 -1.754895  3.605710 -0.221714
# 31425  1.255461 -2.389366 -1.667758  2.717643 -0.513780 -0.096323 -1.179428
# 44160 -1.674279 -1.408685 -0.771994 -3.313224  1.083896 -1.256943 -0.776987
#
#            pca7      pca8      pca9
# 46169  0.278190  0.281827  1.605078
# 38354 -1.305266 -1.968634  0.893199
# 25598  1.401280 -1.335410  0.115083
# 5235  -0.188423  0.077517  0.066978
# 10009  0.074799  0.302472  0.210891
# ...         ...       ...       ...
# 32846 -1.141452 -0.453824  0.307969
# 35648  0.106073  0.078665 -1.253113
# 6527   1.161345  0.423613  1.544952
# 31425  0.413471  0.396633 -0.003396
# 44160  0.335202 -0.424370  1.852493
#
# [12462 rows x 10 columns]

# %% [markdown]
# ## Feature Aggregation
#
# Use grouping to create new features. For example, we can group by manufacturer and then calculate the average fuel economy for each manufacturer.

# %%
# Create a transformer to add mean and std for y for a given column in X
from sklearn.base import BaseEstimator, TransformerMixin

class AddMeanStd(BaseEstimator, TransformerMixin):
    def __init__(self, col, missing_mean_val, missing_std_val):
        self.col = col
        # attribute names must be the same as the constructor args
        self.missing_mean_val = missing_mean_val
        self.missing_std_val = missing_std_val
        # track values for each group in col
        self.means = {}
        self.stds = {}
    
    def fit(self, X, y=None):
        assert y.name not in X.columns
        with_y = X.assign(y=y)
        self.means = with_y.groupby(self.col)['y'].mean().to_dict()
        self.stds = with_y.groupby(self.col)['y'].std().to_dict()
        return self
    
    def transform(self, X):
        # add mean and std for each row
        return X.assign(**{
            f'{self.col}_mean': X[self.col].map(self.means).fillna(self.missing_mean_val),
            f'{self.col}_std': X[self.col].map(self.stds).fillna(self.missing_std_val)
        })

# %%
# Create Pipeline wtih Aggregation
from sklearn.decomposition import PCA
# replace hashing encoder with target encoder for high cardinality columns

from category_encoders import hashing
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder, TargetEncoder


# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# create pipeline fill cylinders with 0 and displ with median

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')
hashing_encoder = hashing.HashingEncoder(n_components=10, drop_invariant=True)
target_encoder = TargetEncoder(target_type='continuous', random_state=42)

def debug_transformer(X, name):
    globals()[name] = X
    return X

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']


# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('one_hot_encoder', one_hot_encoder, low_cardinality_cols),
        #('hashing_encoder', hashing_encoder, high_cardinality_cols)
        ('target_encoder', target_encoder, high_cardinality_cols)
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[
    ('string_converter', PyArrowStringConverter()),
    ('make_mean_std', AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
    ('preprocessor', preprocessor), 
    ('std_scaler', std_scaler),
    #('pca', PCA(n_components=10)),
    ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),    
    #  ('minmax_scaler', minmax_scaler, ['range']),
    ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('string_converter', PyArrowStringConverter()),
#                 ('make_mean_std',
#                  AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ'])...
#                                                                 sparse_output=False),
#                                                   ['VClass', 'drive',
#                                                    'fuelType', 'trany']),
#                                                  ('target_encoder',
#                                                   TargetEncoder(random_state=42,
#                                                                 target_type='continuous'),
#                                                   ['make', 'model', 'eng_dscr',
#                                                    'evMotor',
#                                                    'trans_dscr'])])),
#                 ('std_scaler', StandardScaler()),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cecd5199e0>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('lr', LinearRegression())])

# %%
pipeline.score(X_test, y_test)
# Out:
# 0.9483640116556957

# %% [markdown]
# ## TFIDF
#
# *Term frequency–inverse document frequency* (TFIDF) is a numerical statistic that is intended to reflect how important a word is to a document in a collection or corpus. It is often used as a feature for text classification.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


def combine_str_cols_transformer(X, cols, new_col_name):
    # tdidf expects a single column of strings
    return X.assign(**{new_col_name: X[cols].fillna('').agg(' '.join, axis='columns')})[new_col_name]

text_pipeline = Pipeline([
    ('combine_str', FunctionTransformer(combine_str_cols_transformer, 
                                        kw_args={'cols': cat_cols, 'new_col_name': 'all_str'})),
    ('tfidf', TfidfVectorizer()), # can't be sparse because of Pandas
    ('combine_debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_combine'})),
    ('make_dense', FunctionTransformer(lambda X: X.toarray())),
    ('pca', PCA(n_components=10)),
])

# %%
text_pipeline.fit_transform(autos[cat_cols])
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_function_transformer.py:305: UserWarning: When `set_output` is configured to be 'pandas', `func` should return a pandas DataFrame to follow the `set_output` API  or `feature_names_out` should be defined.
#   warnings.warn(warn_msg.format("pandas"))
#            pca0      pca1      pca2      pca3      pca4      pca5      pca6  \
# 0     -0.068733 -0.077423  0.006569  0.065277  0.111230  0.073577  0.131312
# 1     -0.076933 -0.082900  0.022145  0.122745  0.149806  0.088512  0.172364
# 2     -0.144446 -0.246812 -0.095316 -0.179602  0.098867 -0.170263  0.158010
# 3      0.038266 -0.122762  0.207183 -0.038365  0.071923  0.203754 -0.023554
# 4     -0.121499 -0.006797 -0.242849 -0.022273  0.102853 -0.010153  0.064825
# ...         ...       ...       ...       ...       ...       ...       ...
# 49841 -0.171653 -0.130810 -0.070111 -0.211064 -0.011905 -0.083656 -0.158631
# 49842 -0.184364 -0.178585 -0.117358 -0.207530  0.014087 -0.158508  0.094170
# 49843 -0.066009  0.013713 -0.226616 -0.147544  0.065212  0.024558 -0.179784
# 49844 -0.076018 -0.027206 -0.270648 -0.143306  0.089410 -0.041055  0.046620
# 49845 -0.112808  0.027110 -0.206798 -0.027067  0.082703  0.044191 -0.124100
#
#            pca7      pca8      pca9
# 0     -0.076877 -0.023826 -0.084889
# 1     -0.143333 -0.069136 -0.116438
# 2     -0.043396  0.139688  0.102628
# 3      0.003056  0.036660  0.095075
# 4      0.031635 -0.100311  0.155712
# ...         ...       ...       ...
# 49841 -0.032037 -0.086625  0.013170
# 49842 -0.007396 -0.113039  0.035397
# 49843  0.043761 -0.079104  0.134291
# 49844  0.066789 -0.102542  0.155549
# 49845  0.012779 -0.080966  0.138281
#
# [49846 rows x 10 columns]

# %%
tmp_combine.shape
# Out:
# (49846, 2871)

# %%
print(tmp_combine)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 679322 stored elements and shape (49846, 2871)>
#   Coords	Values
#   (0, 728)	0.3640439340173063
#   (0, 2231)	0.3640439340173063
#   (0, 2434)	0.36603465073776786
#   (0, 2697)	0.529414390943194
#   (0, 142)	0.4288651548311602
#   (0, 1837)	0.1178621406091469
#   (0, 2422)	0.06914328042642544
#   (0, 2185)	0.1090672540640998
#   (0, 2759)	0.05197901474836046
#   (0, 1211)	0.05197901474836046
#   (0, 2643)	0.20235127989551585
#   (0, 2327)	0.20235127989551585
#   (0, 1391)	0.11393123657150202
#   (0, 2192)	0.0769009584567004
#   (1, 1837)	0.16817042453560635
#   (1, 2422)	0.09865640283640026
#   (1, 2185)	0.15562152803348156
#   (1, 2759)	0.07416574085619429
#   (1, 1211)	0.07416574085619429
#   (1, 2643)	0.28872291364705865
#   (1, 2327)	0.28872291364705865
#   (1, 2192)	0.10972536867241225
#   (1, 1388)	0.44417254967257047
#   (1, 2568)	0.6506011973608858
#   (1, 1556)	0.3569786802035705
#   :	:
#   (49844, 1391)	0.20174857393716106
#   (49844, 2192)	0.13617563690097703
#   (49844, 987)	0.1605586924952376
#   (49844, 2491)	0.4372595026209331
#   (49844, 1736)	0.582779542720721
#   (49844, 808)	0.3190992099996952
#   (49844, 2002)	0.2527678859650229
#   (49844, 729)	0.20916372186620258
#   (49844, 1076)	0.27160646310464276
#   (49845, 2422)	0.10095180934833764
#   (49845, 2759)	0.15178266216554728
#   (49845, 1211)	0.07589133108277364
#   (49845, 1391)	0.16634392239207257
#   (49845, 987)	0.13238241124876166
#   (49845, 790)	0.09710248255887496
#   (49845, 2491)	0.3605252783190814
#   (49845, 1736)	0.4805081549484349
#   (49845, 808)	0.2631008149782211
#   (49845, 2637)	0.41069633872480044
#   (49845, 2002)	0.20840990736950776
#   (49845, 729)	0.17245779357124835
#   (49845, 1076)	0.2239425218139898
#   (49845, 2615)	0.35009092483009846
#   (49845, 2093)	0.16005337594064026
#   (49845, 1050)	0.1900513335565397

# %%
# Add TFIDF to combination of string columns
from sklearn.decomposition import PCA
# replace hashing encoder with target encoder for high cardinality columns

from category_encoders import hashing
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder, TargetEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
# import pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer


# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# create pipeline fill cylinders with 0 and displ with median

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')
hashing_encoder = hashing.HashingEncoder(n_components=10, drop_invariant=True)
target_encoder = TargetEncoder(target_type='continuous', random_state=42)

def debug_transformer(X, name):
    globals()[name] = X
    return X

def combine_str_cols_transformer(X, cols, new_col_name):
    # tdidf expects a single column of strings
    return X.assign(**{new_col_name: X[cols].fillna('').agg(' '.join, axis='columns')})[new_col_name]

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']


text_pipeline = Pipeline([
    ('combine_str', FunctionTransformer(combine_str_cols_transformer, 
                                        kw_args={'cols': cat_cols, 'new_col_name': 'all_str'})),
    ('tfidf', TfidfVectorizer()), # can't be sparse because of Pandas
    ('combine_debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_combine'})),
    ('make_dense', FunctionTransformer(lambda X: X.toarray())),
    ('pca', PCA(n_components=10)),
])

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('one_hot_encoder', one_hot_encoder, low_cardinality_cols),
        #('hashing_encoder', hashing_encoder, high_cardinality_cols)
        ('target_encoder', target_encoder, high_cardinality_cols),
        ('text', text_pipeline, cat_cols)
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[
    ('string_converter', PyArrowStringConverter()),
    ('make_mean_std', AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
    ('preprocessor', preprocessor), 
    ('std_scaler', std_scaler),
    #('pca', PCA(n_components=10)),
    ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),    
    #  ('minmax_scaler', minmax_scaler, ['range']),
    ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_function_transformer.py:305: UserWarning: When `set_output` is configured to be 'pandas', `func` should return a pandas DataFrame to follow the `set_output` API  or `feature_names_out` should be defined.
#   warnings.warn(warn_msg.format("pandas"))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 82
#      71 pipeline = Pipeline(steps=[
#      72     ('string_converter', PyArrowStringConverter()),
#      73     ('make_mean_std', AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
#    (...)     78     #  ('minmax_scaler', minmax_scaler, ['range']),
#      79     ('lr', LinearRegression())])
#      81 # fit the pipeline
# ---> 82 pipeline.fit(X_train, y_train)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/pipeline.py:613, in Pipeline.fit(self, X, y, **params)
#     606     raise ValueError(
#     607         "The `transform_input` parameter can only be set if metadata "
#     608         "routing is enabled. You can enable metadata routing using "
#     609         "`sklearn.set_config(enable_metadata_routing=True)`."
#     610     )
#     612 routed_params = self._check_method_params(method="fit", props=params)
# --> 613 Xt = self._fit(X, y, routed_params, raw_params=params)
#     614 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     615     if self._final_estimator != "passthrough":
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/pipeline.py:547, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     540 # Fit or load from cache the current transformer
#     541 step_params = self._get_metadata_for_step(
#     542     step_idx=step_idx,
#     543     step_params=routed_params[name],
#     544     all_params=raw_params,
#     545 )
# --> 547 X, fitted_transformer = fit_transform_one_cached(
#     548     cloned_transformer,
#     549     X,
#     550     y,
#     551     weight=None,
#     552     message_clsname="Pipeline",
#     553     message=self._log_message(step_idx),
#     554     params=step_params,
#     555 )
#     556 # Replace the transformer of the step with the fitted
#     557 # transformer. This is necessary when loading the transformer
#     558 # from the cache.
#     559 self.steps[step_idx] = (name, fitted_transformer)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/joblib/memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/pipeline.py:1484, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1482 with _print_elapsed_time(message_clsname, message):
#    1483     if hasattr(transformer, "fit_transform"):
# -> 1484         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1485     else:
#    1486         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1487             X, **params.get("transform", {})
#    1488         )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:1029, in ColumnTransformer.fit_transform(self, X, y, **params)
#    1026 self._validate_output(Xs)
#    1027 self._record_output_indices(Xs)
# -> 1029 return self._hstack(list(Xs), n_samples=n_samples)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:1213, in ColumnTransformer._hstack(self, Xs, n_samples)
#    1211     output_samples = output.shape[0]
#    1212     if output_samples != n_samples:
# -> 1213         raise ValueError(
#    1214             "Concatenating DataFrames from the transformer's output lead to"
#    1215             " an inconsistent number of samples. The output may have Pandas"
#    1216             " Indexes that do not match, or that transformers are returning"
#    1217             " number of samples which are not the same as the number input"
#    1218             " samples."
#    1219         )
#    1221     return output
#    1223 return np.hstack(Xs)
#
# ValueError: Concatenating DataFrames from the transformer's output lead to an inconsistent number of samples. The output may have Pandas Indexes that do not match, or that transformers are returning number of samples which are not the same as the number input samples.

# %%
# convert text pipeline to sklearn transformer so we can keep in pandas
# and preserve index
from sklearn.base import BaseEstimator, TransformerMixin


def combine_str_cols_transformer(X, cols, new_col_name):
    # tdidf expects a single column of strings
    return X.assign(**{new_col_name: X[cols].fillna('').agg(' '.join, axis='columns')})[new_col_name]


class TextPipeline(BaseEstimator, TransformerMixin):
    def __init__(self, cat_cols):
        self.cat_cols = cat_cols
        self.text_pipeline = Pipeline([
            ('combine_str', FunctionTransformer(combine_str_cols_transformer, 
                                                kw_args={'cols': cat_cols, 'new_col_name': 'all_str'})),
            ('tfidf', TfidfVectorizer()), # can't be sparse because of Pandas
            ('make_dense', FunctionTransformer(lambda X: X.toarray())),
            ('pca', PCA(n_components=10)),
        ])

    def fit(self, X, y=None):
        self.text_pipeline.fit(X, y)
        return self
    
    def transform(self, X):
        res = self.text_pipeline.transform(X)
        # replace index with X index
        df = (res
              .assign(index=X.index)
              .set_index('index')
        )
        return df

# %%
# test the pipeline
text_pipeline = TextPipeline(cat_cols)
text_pipeline.fit(X_train, y_train)
text_pipeline.transform(X_train)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_function_transformer.py:305: UserWarning: When `set_output` is configured to be 'pandas', `func` should return a pandas DataFrame to follow the `set_output` API  or `feature_names_out` should be defined.
#   warnings.warn(warn_msg.format("pandas"))
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_function_transformer.py:305: UserWarning: When `set_output` is configured to be 'pandas', `func` should return a pandas DataFrame to follow the `set_output` API  or `feature_names_out` should be defined.
#   warnings.warn(warn_msg.format("pandas"))
#            pca0      pca1      pca2      pca3      pca4      pca5      pca6  \
# index
# 44707 -0.151010 -0.118369 -0.035068  0.105485  0.140130 -0.020038  0.111200
# 27296 -0.175304 -0.015200 -0.005672  0.185621  0.052584  0.000467  0.212764
# 13095 -0.130595  0.011571 -0.225223  0.061942  0.081927 -0.054156  0.017393
# 48291 -0.116974 -0.068900 -0.012297 -0.055562  0.015441 -0.043820  0.002676
# 11146 -0.160550 -0.193336 -0.085541 -0.189098  0.043081 -0.165525  0.120083
# ...         ...       ...       ...       ...       ...       ...       ...
# 11284  0.223653  0.064498  0.414394 -0.079506  0.126918 -0.002006 -0.100125
# 44732 -0.158342 -0.124356 -0.019203 -0.153563  0.025575 -0.099077 -0.118549
# 38158  0.453891 -0.264475  0.268166  0.184017 -0.102921 -0.062089 -0.028205
# 860   -0.208170 -0.120144 -0.035660 -0.047918  0.054394 -0.086703 -0.109354
# 15795 -0.107909 -0.036197  0.015573 -0.066611 -0.078530 -0.000031 -0.150166
#
#            pca7      pca8      pca9
# index
# 44707 -0.066358  0.099869  0.069871
# 27296 -0.096704 -0.195286 -0.054820
# 13095  0.014473 -0.233977  0.132559
# 48291 -0.003700  0.103015 -0.002789
# 11146 -0.036293 -0.117866 -0.014407
# ...         ...       ...       ...
# 11284 -0.099120 -0.028431  0.094065
# 44732 -0.060197  0.154696  0.046288
# 38158  0.063549 -0.020264 -0.010389
# 860   -0.115374  0.105169  0.050629
# 15795  0.017087  0.003296 -0.071759
#
# [37384 rows x 10 columns]

# %%
# Add TFIDF to combination of string columns
from sklearn.decomposition import PCA
# replace hashing encoder with target encoder for high cardinality columns

from category_encoders import hashing
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder, TargetEncoder
from sklearn.feature_extraction.text import TfidfVectorizer


# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# create pipeline fill cylinders with 0 and displ with median

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')
hashing_encoder = hashing.HashingEncoder(n_components=10, drop_invariant=True)
target_encoder = TargetEncoder(target_type='continuous', random_state=42)

def debug_transformer(X, name):
    globals()[name] = X
    return X

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('one_hot_encoder', one_hot_encoder, low_cardinality_cols),
        #('hashing_encoder', hashing_encoder, high_cardinality_cols)
        ('target_encoder', target_encoder, high_cardinality_cols),
        ('text', TextPipeline(cat_cols), cat_cols)
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[
    ('string_converter', PyArrowStringConverter()),
    ('make_mean_std', AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
    ('preprocessor', preprocessor), 
    ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),        
    ('std_scaler', std_scaler),
    #('pca', PCA(n_components=10)),
    #  ('minmax_scaler', minmax_scaler, ['range']),
    ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_function_transformer.py:305: UserWarning: When `set_output` is configured to be 'pandas', `func` should return a pandas DataFrame to follow the `set_output` API  or `feature_names_out` should be defined.
#   warnings.warn(warn_msg.format("pandas"))
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_function_transformer.py:305: UserWarning: When `set_output` is configured to be 'pandas', `func` should return a pandas DataFrame to follow the `set_output` API  or `feature_names_out` should be defined.
#   warnings.warn(warn_msg.format("pandas"))
# Pipeline(steps=[('string_converter', PyArrowStringConverter()),
#                 ('make_mean_std',
#                  AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ'])...
#                                                   TextPipeline(cat_cols=['make',
#                                                                          'model',
#                                                                          'trany',
#                                                                          'drive',
#                                                                          'VClass',
#                                                                          'eng_dscr',
#                                                                          'evMotor',
#                                                                          'fuelType',
#                                                                          'trans_dscr']),
#                                                   ['make', 'model', 'trany',
#                                                    'drive', 'VClass',
#                                                    'eng_dscr', 'evMotor',
#                                                    'fuelType',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cec6ac4720>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
pipeline.score(X_test, y_test)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_function_transformer.py:305: UserWarning: When `set_output` is configured to be 'pandas', `func` should return a pandas DataFrame to follow the `set_output` API  or `feature_names_out` should be defined.
#   warnings.warn(warn_msg.format("pandas"))
# 0.9493328419417173

# %% [markdown]
# ## Text Embeddings
#
# *Text embeddings* are a type of feature extraction that is used for text data. They are a numerical representation of text that can be used in machine learning algorithms. They are often used as a feature for text classification. A common example is a vector to represent man, woman, and king. When you add the difference between woman and man to king, you get queen.
#
# We will use the Spacy library to create text embeddings. Spacy is a library for natural language processing (NLP).

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (0.25.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.12/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from spacy) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from spacy) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in /home/codespace/.local/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in /usr/local/python/3.12.1/lib/python3.12/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2->spacy) (3.0.3)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# install spacy language model
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 32.4 MB/s  0:00:00m0:00:01
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from sklearn.base import TransformerMixin, BaseEstimator

class SpacyEmbeddingVectorizer(TransformerMixin, BaseEstimator):
    def __init__(self, columns):
        # Load the SpaCy model
        self.nlp = spacy.load("en_core_web_sm")
        self.columns = columns
        
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        text = (X[self.columns].fillna('').apply(lambda x: ' '.join(x), axis='columns'))
        res = [self.nlp(row).vector for row in text]
        df = pd.DataFrame(res, index=X.index)
        return df

# %%
# try it out on cat_cols - takes 4+ minutes on my machine
# using sample to speed up

embeds = SpacyEmbeddingVectorizer(cat_cols)
embeds.fit_transform(X_train.sample(1_000, random_state=42))
# Out:
#              0         1         2         3         4         5         6   \
# 45420 -0.218441 -0.568995 -0.046867  0.652951  0.379165  0.254823  0.027286
# 4676  -0.066303 -0.575151 -0.012721  0.682128  0.127210 -0.009319  0.226363
# 26379 -0.095782 -0.598008 -0.157102  0.548713  0.229994 -0.051816  0.282933
# 34381 -0.282546 -0.614810  0.227111  0.719862  0.104562  0.431375  0.303337
# 29441 -0.182519 -0.666673  0.173558  0.737220  0.517232  0.129387  0.084240
# ...         ...       ...       ...       ...       ...       ...       ...
# 41427 -0.095382 -0.626155  0.103352  0.648943  0.368107  0.318959  0.362489
# 10233  0.003758 -0.588571  0.296336  0.684211  0.550117  0.151603  0.055065
# 19930 -0.181514 -0.628682  0.051174  0.484864  0.297504  0.569619 -0.034987
# 24816 -0.063862 -0.639397  0.054161  0.689551  0.263735  0.098369  0.148780
# 28386 -0.183590 -0.572783  0.371234  0.920906  0.234124  0.298188  0.199676
#
#              7         8         9   ...        86        87        88  \
# 45420  0.233028  0.178629 -0.465710  ...  0.360992  0.015084 -0.706340
# 4676   0.196583  0.026892 -0.433967  ...  0.455348 -0.047833 -0.584811
# 26379  0.323679 -0.030146 -0.317061  ...  0.404462 -0.005401 -0.717852
# 34381  0.122929 -0.143511 -0.433796  ...  0.264992  0.002756 -0.705202
# 29441  0.217116  0.054634 -0.340153  ...  0.383667 -0.267973 -0.593457
# ...         ...       ...       ...  ...       ...       ...       ...
# 41427  0.287199  0.034806 -0.341611  ...  0.248388 -0.096695 -0.692671
# 10233  0.284969  0.129350 -0.262640  ...  0.392109 -0.150471 -0.742213
# 19930  0.350881  0.232039 -0.413759  ...  0.481787  0.176418 -0.765529
# 24816  0.126934  0.011269 -0.479199  ...  0.333687 -0.058435 -0.604455
# 28386  0.235077  0.114893 -0.436305  ...  0.286524 -0.082355 -0.675107
#
#              89        90        91        92        93        94        95
# 45420  0.492494  0.004625  0.131663  0.164428  0.271198  0.256640  0.367141
# 4676   0.139763  0.040493  0.017100  0.394849  0.134939  0.120770  0.129784
# 26379  0.380490 -0.110396  0.133283  0.257406  0.102377  0.346548  0.216914
# 34381  0.358261 -0.109862 -0.017466  0.232781  0.109662  0.221306  0.255282
# 29441  0.392498  0.030078  0.023607  0.057887  0.223377  0.221577  0.229190
# ...         ...       ...       ...       ...       ...       ...       ...
# 41427  0.420129 -0.049164  0.050781  0.218773  0.299599  0.248009  0.231242
# 10233  0.388854 -0.053382 -0.070885  0.056529  0.195054  0.268072  0.242655
# 19930  0.460026  0.049531  0.186292  0.205660  0.001450  0.145504  0.281051
# 24816  0.072676  0.006581 -0.104465  0.467841  0.192086  0.293905  0.109998
# 28386  0.557601  0.189718  0.097167  0.154039  0.156197  0.181268  0.380471
#
# [1000 rows x 96 columns]

# %%
# Add embeddings
from sklearn.decomposition import PCA
# replace hashing encoder with target encoder for high cardinality columns

from category_encoders import hashing
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder, TargetEncoder
from sklearn.feature_extraction.text import TfidfVectorizer


# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# create pipeline fill cylinders with 0 and displ with median

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')
hashing_encoder = hashing.HashingEncoder(n_components=10, drop_invariant=True)
target_encoder = TargetEncoder(target_type='continuous', random_state=42)

def debug_transformer(X, name):
    globals()[name] = X
    return X

def combine_str_cols_transformer(X, cols, new_col_name):
    # tdidf expects a single column of strings
    return X.assign(**{new_col_name: X[cols].agg(' '.join, axis='columns')})[new_col_name]

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('one_hot_encoder', one_hot_encoder, low_cardinality_cols),
        #('hashing_encoder', hashing_encoder, high_cardinality_cols)
        ('target_encoder', target_encoder, high_cardinality_cols),
        ('text', SpacyEmbeddingVectorizer(cat_cols), cat_cols)
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[
    ('string_converter', PyArrowStringConverter()),
    ('make_mean_std', AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
    ('preprocessor', preprocessor), 
    ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),        
    ('std_scaler', std_scaler),
    #('pca', PCA(n_components=10)),
    #  ('minmax_scaler', minmax_scaler, ['range']),
    ('lr', LinearRegression())])

# fit the pipeline
limit = 1_000
pipeline.fit(X_train.iloc[:limit], y_train.iloc[:limit])
# Out:
# Pipeline(steps=[('string_converter', PyArrowStringConverter()),
#                 ('make_mean_std',
#                  AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['cylinders']),
#                                                  ('displ_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['displ'])...
#                                                   SpacyEmbeddingVectorizer(columns=['make',
#                                                                                     'model',
#                                                                                     'trany',
#                                                                                     'drive',
#                                                                                     'VClass',
#                                                                                     'eng_dscr',
#                                                                                     'evMotor',
#                                                                                     'fuelType',
#                                                                                     'trans_dscr']),
#                                                   ['make', 'model', 'trany',
#                                                    'drive', 'VClass',
#                                                    'eng_dscr', 'evMotor',
#                                                    'fuelType',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78ceb9f904a0>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
pipeline.score(X_test, y_test)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:261: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(msg, UserWarning)
# 0.9196676139383444

# %% [markdown]
# ## Challenge: Feature Extraction
#
# Create a model that predicts mileage based on the spacy embeddings of the text columns

# %% [markdown]
# ## Solution: Feature Extraction

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Create a model using only SpaCy text embeddings from the text columns
column_transformers = ColumnTransformer(
        transformers=[
                ('text', SpacyEmbeddingVectorizer(cat_cols), cat_cols)
        ],
        remainder='drop'  # drop everything else
)

pipeline = Pipeline(steps=[
    ('preprocessor', column_transformers),
    ('scaler', StandardScaler()),
    ('regressor', LinearRegression())
])

limit = min(1000, X_train.shape[0])
pipeline.fit(X_train.iloc[:limit], y_train.iloc[:limit])

y_pred = pipeline.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f'Test MSE: {mse:.3f}')
print(f'Test RMSE: {rmse:.3f}')
print(f'Test R2: {r2:.3f}')
# Out:
# Test MSE: 101.520
# Test RMSE: 10.076
# Test R2: 0.538

# %%
pipeline.score(X_test, y_test)
# Out:
# 0.5375314950942993

# %% [markdown]
# # Temporal Features
#
# Time based data often has trends and seasonality. We can extract features from the date and time to capture these patterns.

# %% [markdown]
# ## Extracting Date and Time Features

# %%
# !pip install feature-engine
# Out:
# Requirement already satisfied: feature-engine in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from feature-engine) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from feature-engine) (2.2.0)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from feature-engine) (1.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from feature-engine) (1.17.1)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from feature-engine) (0.14.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=2.2.0->feature-engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas>=2.2.0->feature-engine) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=2.2.0->feature-engine) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->feature-engine) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn>=1.4.0->feature-engine) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn>=1.4.0->feature-engine) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels>=0.11.1->feature-engine) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels>=0.11.1->feature-engine) (26.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# use feature-engine library to pull out date features

from feature_engine.datetime import DatetimeFeatures

dtf = DatetimeFeatures(features_to_extract='all')
dtf.fit_transform(autos[['createdOn']])
# Out:
#        createdOn_month  createdOn_quarter  createdOn_semester  createdOn_year  \
# 0                    1                  1                   1            2013
# 1                    1                  1                   1            2013
# 2                    1                  1                   1            2013
# 3                    1                  1                   1            2013
# 4                    1                  1                   1            2013
# ...                ...                ...                 ...             ...
# 49841                1                  1                   1            2013
# 49842                1                  1                   1            2013
# 49843                1                  1                   1            2013
# 49844                1                  1                   1            2013
# 49845                1                  1                   1            2013
#
#        createdOn_week  createdOn_day_of_week  createdOn_day_of_month  \
# 0                   1                      1                       1
# 1                   1                      1                       1
# 2                   1                      1                       1
# 3                   1                      1                       1
# 4                   1                      1                       1
# ...               ...                    ...                     ...
# 49841               1                      1                       1
# 49842               1                      1                       1
# 49843               1                      1                       1
# 49844               1                      1                       1
# 49845               1                      1                       1
#
#        createdOn_day_of_year  createdOn_weekend  createdOn_month_start  \
# 0                          1                  0                      1
# 1                          1                  0                      1
# 2                          1                  0                      1
# 3                          1                  0                      1
# 4                          1                  0                      1
# ...                      ...                ...                    ...
# 49841                      1                  0                      1
# 49842                      1                  0                      1
# 49843                      1                  0                      1
# 49844                      1                  0                      1
# 49845                      1                  0                      1
#
#        createdOn_month_end  createdOn_quarter_start  createdOn_quarter_end  \
# 0                        0                        1                      0
# 1                        0                        1                      0
# 2                        0                        1                      0
# 3                        0                        1                      0
# 4                        0                        1                      0
# ...                    ...                      ...                    ...
# 49841                    0                        1                      0
# 49842                    0                        1                      0
# 49843                    0                        1                      0
# 49844                    0                        1                      0
# 49845                    0                        1                      0
#
#        createdOn_year_start  createdOn_year_end  createdOn_leap_year  \
# 0                         1                   0                    0
# 1                         1                   0                    0
# 2                         1                   0                    0
# 3                         1                   0                    0
# 4                         1                   0                    0
# ...                     ...                 ...                  ...
# 49841                     1                   0                    0
# 49842                     1                   0                    0
# 49843                     1                   0                    0
# 49844                     1                   0                    0
# 49845                     1                   0                    0
#
#        createdOn_days_in_month  createdOn_hour  createdOn_minute  \
# 0                           31               0                 0
# 1                           31               0                 0
# 2                           31               0                 0
# 3                           31               0                 0
# 4                           31               0                 0
# ...                        ...             ...               ...
# 49841                       31               0                 0
# 49842                       31               0                 0
# 49843                       31               0                 0
# 49844                       31               0                 0
# 49845                       31               0                 0
#
#        createdOn_second
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 49841                 0
# 49842                 0
# 49843                 0
# 49844                 0
# 49845                 0
#
# [49846 rows x 20 columns]

# %% [markdown]
# ## Seasonality and Trend
#
# We can use the `seasonal_decompose` function from `statsmodels`` to decompose a time series into its components.

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels) (1.17.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels) (2.2.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

seasonal_decompose?
# Out:
# Signature:
# seasonal_decompose(
#     x,
#     model='additive',
#     filt=None,
#     period=None,
#     two_sided=True,
#     extrapolate_trend=0,
# )
# Docstring:
# Seasonal decomposition using moving averages.
#
# Parameters
# ----------
# x : array_like
#     Time series. If 2d, individual series are in columns. x must contain 2
#     complete cycles.
# model : {"additive", "multiplicative"}, optional
#     Type of seasonal component. Abbreviations are accepted.
# filt : array_like, optional
#     The filter coefficients for filtering out the seasonal component.
#     The concrete moving average method used in filtering is determined by
#     two_sided.
# period : int, optional
#     Period of the series (e.g., 1 for annual, 4 for quarterly, etc). Must
#     be used if x is not a pandas object or if the index of x does not have
#     a frequency. Overrides default periodicity of x if x is a pandas
#     object with a timeseries index.
# two_sided : bool, optional
#     The moving average method used in filtering.
#     If True (default), a centered moving average is computed using the
#     filt. If False, the filter coefficients are for past values only.
# extrapolate_trend : int or 'freq', optional
#     If set to > 0, the trend resulting from the convolution is
#     linear least-squares extrapolated on both ends (or the single one
#     if two_sided is False) considering this many (+1) closest points.
#     If set to 'freq', use `freq` closest points. Setting this parameter
#     results in no NaN values in trend or resid components.
#
# Returns
# -------
# DecomposeResult
#     A object with seasonal, trend, and resid attributes.
#
# See Also
# --------
# statsmodels.tsa.filters.bk_filter.bkfilter
#     Baxter-King filter.
# statsmodels.tsa.filters.cf_filter.cffilter
#     Christiano-Fitzgerald asymmetric, random walk filter.
# statsmodels.tsa.filters.hp_filter.hpfilter
#     Hodrick-Prescott filter.
# statsmodels.tsa.filters.convolution_filter
#     Linear filtering via convolution.
# statsmodels.tsa.seasonal.STL
#     Season-Trend decomposition using LOESS.
#
# Notes
# -----
# This is a naive decomposition. More sophisticated methods should
# be preferred.
#
# The additive model is Y[t] = T[t] + S[t] + e[t]
#
# The multiplicative model is Y[t] = T[t] * S[t] * e[t]
#
# The results are obtained by first estimating the trend by applying
# a convolution filter to the data. The trend is then removed from the
# series and the average of this de-trended series for each period is
# the returned seasonal component.
# File:      /usr/local/python/3.12.1/lib/python3.12/site-packages/statsmodels/tsa/seasonal.py
# Type:      function

# %%
ford = (autos
        .query("make == 'Ford'")
        #.groupby(pd.Grouper(key='createdOn', freq='ME'))
        .groupby('year')
        .city08
        .median()
        .ffill())
ford
# Out:
# year
# 1984    14.5
# 1985    15.0
# 1986    16.0
# 1987    15.0
# 1988    15.0
# 1989    15.0
# 1990    15.0
# 1991    15.0
# 1992    15.0
# 1993    15.0
# 1994    15.0
# 1995    15.0
# 1996    15.0
# 1997    15.0
# 1998    14.0
# 1999    14.0
# 2000    15.0
# 2001    15.0
# 2002    14.5
# 2003    15.0
# 2004    15.0
# 2005    16.0
# 2006    15.0
# 2007    15.0
# 2008    15.0
# 2009    16.0
# 2010    17.0
# 2011    17.0
# 2012    18.0
# 2013    18.0
# 2014    18.0
# 2015    20.0
# 2016    19.0
# 2017    18.0
# 2018    19.0
# 2019    19.0
# 2020    20.0
# 2021    20.0
# 2022    20.0
# 2023    19.0
# 2024    19.0
# 2025    19.0
# 2026    19.0
# Name: city08, dtype: float64

# %%
# example of 5 year decomposition (period=5 on yearly data)
from matplotlib import pyplot as plt
decomposition = seasonal_decompose(ford, model='additive', period=5)

# Plot the decomposition
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(15, 8))
ford.plot(ax=ax1, title='Original')
decomposition.trend.plot(ax=ax2, title='Trend')
decomposition.seasonal.plot(ax=ax3, title='Seasonality')
decomposition.resid.plot(ax=ax4, title='Residuals')
fig.tight_layout()

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose

def get_seasonal(group, time_col, agg_col, period=1):
    # Sort by date and set index
    group = group.sort_values(time_col)
    # rename index to index
    group.index.name = 'index'
    ts = group.set_index(time_col)[agg_col]

    # Handle groups with insufficient data
    if len(ts) < 2:
        return group.assign(seasonal=0, trend=0, resid=0)

    # Decompose the time series
    res = seasonal_decompose(ts, model='additive', period=period, extrapolate_trend='freq')

    # Reassign the decomposed components to the group
    return (group
            .assign(seasonal=res.seasonal.values,
                    trend=res.trend.values,
                    resid=res.resid.values))

def add_seasonal(df, time_col, group_cols, agg_col):
    all_group_cols = [time_col] + group_cols
    return (df
            .groupby(group_cols)
            .apply(get_seasonal, time_col=time_col, agg_col=agg_col, period=1)
            .drop(columns=group_cols)
            .reset_index(drop=False)
            .set_index('index')
            .loc[df.index]
    )


# Example usage
res = add_seasonal(X, 'year', ['make'], agg_col='barrels08')
# Out:
# /tmp/ipykernel_3681/4163569392.py:29: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(get_seasonal, time_col=time_col, agg_col=agg_col, period=1)

# %%
res.iloc[:, -5:]
# Out:
#       fuelType trans_dscr  seasonal      trend  resid
# 0      Regular        NaN       0.0  14.167143    0.0
# 1      Regular        NaN       0.0  27.046364    0.0
# 2      Regular        SIL       0.0  11.018889    0.0
# 3      Regular        NaN       0.0  27.046364    0.0
# 4      Premium        NaN       0.0  15.658421    0.0
# ...        ...        ...       ...        ...    ...
# 49841  Regular      CLKUP       0.0  13.523182    0.0
# 49842  Regular        NaN       0.0  12.935217    0.0
# 49843  Regular      CLKUP       0.0  14.167143    0.0
# 49844  Regular        NaN       0.0  14.167143    0.0
# 49845  Premium      CLKUP       0.0  16.528333    0.0
#
# [49846 rows x 5 columns]

# %%
# Create Pipeline wtih Aggregation
from sklearn.decomposition import PCA
# replace hashing encoder with target encoder for high cardinality columns

from category_encoders import hashing
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder, TargetEncoder


# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# create pipeline fill cylinders with 0 and displ with median

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')
hashing_encoder = hashing.HashingEncoder(n_components=10, drop_invariant=True)
target_encoder = TargetEncoder(target_type='continuous', random_state=42)

def debug_transformer(X, name):
    globals()[name] = X
    return X

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']

# create the seasonal transformer
class SeasonTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, time_col, group_cols, agg_col):
        self.time_col = time_col
        self.group_cols = group_cols
        self.agg_col = agg_col

    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        return add_seasonal(X, self.time_col, self.group_cols, self.agg_col)
        

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('one_hot_encoder', one_hot_encoder, low_cardinality_cols),
        #('hashing_encoder', hashing_encoder, high_cardinality_cols)
        ('target_encoder', target_encoder, high_cardinality_cols),
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[
    ('string_converter', PyArrowStringConverter()),
    ('make_mean_std', AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
        ('seasonal_decompose', SeasonTransformer(time_col='year', group_cols=['make'], agg_col='barrels08')),
#          ['year', 'make', 
#           'barrels08']),  # need to make sure we pass all columns needed

    ('preprocessor', preprocessor), 
    ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),    
    ('std_scaler', std_scaler),
    #('pca', PCA(n_components=10)),

    #  ('minmax_scaler', minmax_scaler, ['range']),
    ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# /tmp/ipykernel_3681/4163569392.py:29: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(get_seasonal, time_col=time_col, agg_col=agg_col, period=1)
# Pipeline(steps=[('string_converter', PyArrowStringConverter()),
#                 ('make_mean_std',
#                  AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
#                 ('seasonal_decompose',
#                  SeasonTransformer(agg_col='barrels08', group_cols=['make'],
#                                    time_col='year')),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=...
#                                                                 sparse_output=False),
#                                                   ['VClass', 'drive',
#                                                    'fuelType', 'trany']),
#                                                  ('target_encoder',
#                                                   TargetEncoder(random_state=42,
#                                                                 target_type='continuous'),
#                                                   ['make', 'model', 'eng_dscr',
#                                                    'evMotor',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cebac8be20>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
pipeline.score(X_test, y_test)
# Out:
# /tmp/ipykernel_3681/4163569392.py:29: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(get_seasonal, time_col=time_col, agg_col=agg_col, period=1)
# 0.9483738485857971

# %% [markdown]
# ## Data for Challenge

# %%
# !pip install openpyxl
# !pip install lxml
# Out:
# Requirement already satisfied: openpyxl in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openpyxl) (2.0.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: lxml in /usr/local/python/3.12.1/lib/python3.12/site-packages (6.1.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# create a model to predict monthly airline passgengers from https://www.transtats.bts.gov/Data_Elements.aspx?Data=1
# for some reason this output is not Excel but HTML
airlines = pd.read_html('data/Passengers_2024.xls')
raw = airlines[0]

# %%
raw
# Out:
#      Year  Month   DOMESTIC  INTERNATIONAL      TOTAL
# 0    2002     10   48054917        9578435   57633352
# 1    2002     11   44850246        9016535   53866781
# 2    2002     12   49684353       10038794   59723147
# 3    2002  TOTAL  551899643      118704850  670604493
# 4    2003      1   43032450        9726436   52758886
# ..    ...    ...        ...            ...        ...
# 270  2023      7   75379256       23475990   98855246
# 271  2023      8   71478927       21664464   93143391
# 272  2023      9   66860476       18974545   85835021
# 273  2023     10   73035601       19095536   92131137
# 274  2023  TOTAL  682960339      194512934  877473273
#
# [275 rows x 5 columns]

# %%
def tweak_airline(df_):
  return (df_
          .query('Month != "TOTAL"')
          .astype({'Month': 'int64'})
          .assign(date=lambda df: pd.to_datetime(df[['Year', 'Month']].assign(day=1)))
  )

air = tweak_airline(raw)

# %%
air
# Out:
#      Year  Month  DOMESTIC  INTERNATIONAL     TOTAL       date
# 0    2002     10  48054917        9578435  57633352 2002-10-01
# 1    2002     11  44850246        9016535  53866781 2002-11-01
# 2    2002     12  49684353       10038794  59723147 2002-12-01
# 4    2003      1  43032450        9726436  52758886 2003-01-01
# 5    2003      2  41166780        8283372  49450152 2003-02-01
# ..    ...    ...       ...            ...       ...        ...
# 269  2023      6  72484376       21928411  94412787 2023-06-01
# 270  2023      7  75379256       23475990  98855246 2023-07-01
# 271  2023      8  71478927       21664464  93143391 2023-08-01
# 272  2023      9  66860476       18974545  85835021 2023-09-01
# 273  2023     10  73035601       19095536  92131137 2023-10-01
#
# [253 rows x 6 columns]

# %% [markdown]
# ## Challenge: Temporal Features
#
# Using the airline data, create a linear regression model to predict the number of passengers for the next month based on the current month.
#
# Then make another model using the `seasonal_decompose` function to add a seasonality component to the model. How do the models compare?

# %% [markdown]
# ## Solution: Temporal Features

# %% [markdown]
# # Feature Selection
#
# *Feature selection* is the process of selecting a subset of features that are most relevant to the target variable. There are many reasons to do this:
#
# -  Simplicity - Fewer features are easier to interpret.
# -  Memory - Fewer features require less memory to store and less computation.
# -  Speed - Fewer features result in faster algorithms.
#
# There are many techniques for feature selection. We will cover a few of them here:
#
# -  Feature importance
# -  Recursive feature elimination

# %% [markdown]
# ## Feature Importance and Weights
#
# Many models can provide a feature importance or weight for each feature. This is a measure of how much the model depends on that feature. We can use this to select the most important features.

# %%
# Create Pipeline wtih Aggregation
from sklearn.decomposition import PCA
# replace hashing encoder with target encoder for high cardinality columns

from category_encoders import hashing
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, OneHotEncoder, TargetEncoder


# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# create pipeline fill cylinders with 0 and displ with median

cylinders_imputer = SimpleImputer(strategy='constant', fill_value=0)
displ_imputer = SimpleImputer(strategy='median')
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
cat_imputer = SimpleImputer(strategy='constant', fill_value='missing')
one_hot_encoder = OneHotEncoder(drop='first', max_categories=10, sparse_output=False, handle_unknown='ignore')
hashing_encoder = hashing.HashingEncoder(n_components=10, drop_invariant=True)
target_encoder = TargetEncoder(target_type='continuous', random_state=42)

def debug_transformer(X, name):
    globals()[name] = X
    return X

cat_cols =  ['make', 'model', 'trany', 'drive', 
            'VClass', 'eng_dscr', 'evMotor', 'fuelType', 'trans_dscr', ]
low_cardinality_cols = ['VClass', 'drive', 'fuelType', 'trany']
high_cardinality_cols = ['make', 'model', 'eng_dscr', 'evMotor', 'trans_dscr']

# create the seasonal transformer
class SeasonTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, time_col, group_cols, agg_col):
        self.time_col = time_col
        self.group_cols = group_cols
        self.agg_col = agg_col

    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        return add_seasonal(X, self.time_col, self.group_cols, self.agg_col)
        

# Create the column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cyl_imputer', cylinders_imputer, ['cylinders']),
        ('displ_imputer', displ_imputer, ['displ']),
        ('one_hot_encoder', one_hot_encoder, low_cardinality_cols),
        #('hashing_encoder', hashing_encoder, high_cardinality_cols)
        ('target_encoder', target_encoder, high_cardinality_cols),
    ],
    remainder='passthrough'
)

# pipeline
pipeline = Pipeline(steps=[
    ('string_converter', PyArrowStringConverter()),
    ('make_mean_std', AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
        ('seasonal_decompose', SeasonTransformer(time_col='year', group_cols=['make'], agg_col='barrels08')),
#          ['year', 'make', 
#           'barrels08']),  # need to make sure we pass all columns needed

    ('preprocessor', preprocessor), 
    ('debug', FunctionTransformer(debug_transformer, kw_args={'name': 'tmp_X'})),    
    ('std_scaler', std_scaler),
    #('pca', PCA(n_components=10)),

    #  ('minmax_scaler', minmax_scaler, ['range']),
    ('lr', LinearRegression())])

# fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# /tmp/ipykernel_3681/4163569392.py:29: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(get_seasonal, time_col=time_col, agg_col=agg_col, period=1)
# Pipeline(steps=[('string_converter', PyArrowStringConverter()),
#                 ('make_mean_std',
#                  AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
#                 ('seasonal_decompose',
#                  SeasonTransformer(agg_col='barrels08', group_cols=['make'],
#                                    time_col='year')),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=...
#                                                                 sparse_output=False),
#                                                   ['VClass', 'drive',
#                                                    'fuelType', 'trany']),
#                                                  ('target_encoder',
#                                                   TargetEncoder(random_state=42,
#                                                                 target_type='continuous'),
#                                                   ['make', 'model', 'eng_dscr',
#                                                    'evMotor',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cebbf836a0>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
pipeline
# Out:
# Pipeline(steps=[('string_converter', PyArrowStringConverter()),
#                 ('make_mean_std',
#                  AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
#                 ('seasonal_decompose',
#                  SeasonTransformer(agg_col='barrels08', group_cols=['make'],
#                                    time_col='year')),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=...
#                                                                 sparse_output=False),
#                                                   ['VClass', 'drive',
#                                                    'fuelType', 'trany']),
#                                                  ('target_encoder',
#                                                   TargetEncoder(random_state=42,
#                                                                 target_type='continuous'),
#                                                   ['make', 'model', 'eng_dscr',
#                                                    'evMotor',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cebbf836a0>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
pipeline.fit(X_train, y_train)
# Out:
# /tmp/ipykernel_3681/4163569392.py:29: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(get_seasonal, time_col=time_col, agg_col=agg_col, period=1)
# Pipeline(steps=[('string_converter', PyArrowStringConverter()),
#                 ('make_mean_std',
#                  AddMeanStd(col='make', missing_mean_val=0, missing_std_val=0)),
#                 ('seasonal_decompose',
#                  SeasonTransformer(agg_col='barrels08', group_cols=['make'],
#                                    time_col='year')),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cyl_imputer',
#                                                   SimpleImputer(fill_value=...
#                                                                 sparse_output=False),
#                                                   ['VClass', 'drive',
#                                                    'fuelType', 'trany']),
#                                                  ('target_encoder',
#                                                   TargetEncoder(random_state=42,
#                                                                 target_type='continuous'),
#                                                   ['make', 'model', 'eng_dscr',
#                                                    'evMotor',
#                                                    'trans_dscr'])])),
#                 ('debug',
#                  FunctionTransformer(func=<function debug_transformer at 0x78cebbf836a0>,
#                                      kw_args={'name': 'tmp_X'})),
#                 ('std_scaler', StandardScaler()), ('lr', LinearRegression())])

# %%
# get linear regression model

lr = pipeline.named_steps['lr']
lr
# Out:
# LinearRegression()

# %%
lr.feature_names_in_
# Out:
# array(['cyl_imputer__cylinders', 'displ_imputer__displ',
#        'one_hot_encoder__VClass_Large Cars',
#        'one_hot_encoder__VClass_Midsize Cars',
#        'one_hot_encoder__VClass_Small Sport Utility Vehicle 4WD',
#        'one_hot_encoder__VClass_Sport Utility Vehicle - 4WD',
#        'one_hot_encoder__VClass_Standard Pickup Trucks',
#        'one_hot_encoder__VClass_Standard Sport Utility Vehicle 4WD',
#        'one_hot_encoder__VClass_Subcompact Cars',
#        'one_hot_encoder__VClass_Two Seaters',
#        'one_hot_encoder__VClass_infrequent_sklearn',
#        'one_hot_encoder__drive_4-Wheel Drive',
#        'one_hot_encoder__drive_4-Wheel or All-Wheel Drive',
#        'one_hot_encoder__drive_All-Wheel Drive',
#        'one_hot_encoder__drive_Front-Wheel Drive',
#        'one_hot_encoder__drive_Part-time 4-Wheel Drive',
#        'one_hot_encoder__drive_Rear-Wheel Drive',
#        'one_hot_encoder__drive_nan',
#        'one_hot_encoder__fuelType_Electricity',
#        'one_hot_encoder__fuelType_Gasoline or E85',
#        'one_hot_encoder__fuelType_Midgrade',
#        'one_hot_encoder__fuelType_Premium',
#        'one_hot_encoder__fuelType_Premium and Electricity',
#        'one_hot_encoder__fuelType_Premium or E85',
#        'one_hot_encoder__fuelType_Regular',
#        'one_hot_encoder__fuelType_Regular Gas and Electricity',
#        'one_hot_encoder__fuelType_infrequent_sklearn',
#        'one_hot_encoder__trany_Automatic (S8)',
#        'one_hot_encoder__trany_Automatic 3-spd',
#        'one_hot_encoder__trany_Automatic 4-spd',
#        'one_hot_encoder__trany_Automatic 5-spd',
#        'one_hot_encoder__trany_Automatic 6-spd',
#        'one_hot_encoder__trany_Manual 4-spd',
#        'one_hot_encoder__trany_Manual 5-spd',
#        'one_hot_encoder__trany_Manual 6-spd',
#        'one_hot_encoder__trany_infrequent_sklearn',
#        'target_encoder__make', 'target_encoder__model',
#        'target_encoder__eng_dscr', 'target_encoder__evMotor',
#        'target_encoder__trans_dscr', 'remainder__year',
#        'remainder__barrels08', 'remainder__range',
#        'remainder__fuelCost08', 'remainder__make_mean',
#        'remainder__make_std', 'remainder__seasonal', 'remainder__trend',
#        'remainder__resid'], dtype=object)

# %%
pd.Series(lr.coef_, index=lr.feature_names_in_)
# Out:
# cyl_imputer__cylinders                                        0.243816
# displ_imputer__displ                                         -0.046640
# one_hot_encoder__VClass_Large Cars                           -0.066920
# one_hot_encoder__VClass_Midsize Cars                          0.133722
# one_hot_encoder__VClass_Small Sport Utility Vehicle 4WD       0.312718
# one_hot_encoder__VClass_Sport Utility Vehicle - 4WD           0.020779
# one_hot_encoder__VClass_Standard Pickup Trucks                0.113534
# one_hot_encoder__VClass_Standard Sport Utility Vehicle 4WD   -0.155616
# one_hot_encoder__VClass_Subcompact Cars                       0.133321
# one_hot_encoder__VClass_Two Seaters                           0.140378
# one_hot_encoder__VClass_infrequent_sklearn                   -0.037112
# one_hot_encoder__drive_4-Wheel Drive                         -0.263875
# one_hot_encoder__drive_4-Wheel or All-Wheel Drive             0.095074
# one_hot_encoder__drive_All-Wheel Drive                       -0.360481
# one_hot_encoder__drive_Front-Wheel Drive                      0.440299
# one_hot_encoder__drive_Part-time 4-Wheel Drive               -0.283274
# one_hot_encoder__drive_Rear-Wheel Drive                       0.049281
# one_hot_encoder__drive_nan                                    0.055298
# one_hot_encoder__fuelType_Electricity                         7.577834
# one_hot_encoder__fuelType_Gasoline or E85                    -1.209787
# one_hot_encoder__fuelType_Midgrade                           -0.090752
# one_hot_encoder__fuelType_Premium                            -1.894942
# one_hot_encoder__fuelType_Premium and Electricity             0.032373
# one_hot_encoder__fuelType_Premium or E85                     -0.188518
# one_hot_encoder__fuelType_Regular                            -3.709079
# one_hot_encoder__fuelType_Regular Gas and Electricity         0.010279
# one_hot_encoder__fuelType_infrequent_sklearn                  0.050903
# one_hot_encoder__trany_Automatic (S8)                         0.163965
# one_hot_encoder__trany_Automatic 3-spd                        0.257720
# one_hot_encoder__trany_Automatic 4-spd                        0.073994
# one_hot_encoder__trany_Automatic 5-spd                       -0.024382
# one_hot_encoder__trany_Automatic 6-spd                       -0.050662
# one_hot_encoder__trany_Manual 4-spd                           0.285143
# one_hot_encoder__trany_Manual 5-spd                           0.194427
# one_hot_encoder__trany_Manual 6-spd                          -0.040220
# one_hot_encoder__trany_infrequent_sklearn                     0.505756
# target_encoder__make                                         -1.084237
# target_encoder__model                                         2.108002
# target_encoder__eng_dscr                                      0.369599
# target_encoder__evMotor                                       2.165527
# target_encoder__trans_dscr                                    0.248899
# remainder__year                                               0.301337
# remainder__barrels08                                          5.347623
# remainder__range                                              0.383112
# remainder__fuelCost08                                        -8.756405
# remainder__make_mean                                          1.530584
# remainder__make_std                                           0.194874
# remainder__seasonal                                           0.000000
# remainder__trend                                             -0.229958
# remainder__resid                                              0.000000
# dtype: float64

# %%
(pd.Series(lr.coef_, index=lr.feature_names_in_)
 .sort_values(key=abs)
 .plot.barh()
)
# Out:
# <Axes: >

# %%
len(lr.feature_names_in_)
# Out:
# 50

# %%
(pd.Series(lr.coef_, index=lr.feature_names_in_)
 .sort_values(key=abs)
 .tail(25)
 .plot.barh()
)
# Out:
# <Axes: >

# %%
# note scale of x axis
(pd.Series(lr.coef_, index=lr.feature_names_in_)
 .sort_values(key=abs)
 .head(26)
 .plot.barh()
)
# Out:
# <Axes: >

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.2.0-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /usr/local/python/3.12.1/lib/python3.12/site-packages (from xgboost) (1.26.4)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Downloading nvidia_nccl_cu12-2.30.4-py3-none-manylinux_2_18_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: scipy in /usr/local/python/3.12.1/lib/python3.12/site-packages (from xgboost) (1.17.1)
# Downloading xgboost-3.2.0-py3-none-manylinux_2_28_x86_64.whl (131.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 47.0 MB/s  0:00:02m0:00:0100:01
# Downloading nvidia_nccl_cu12-2.30.4-py3-none-manylinux_2_18_x86_64.whl (300.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.2/300.2 MB 38.4 MB/s  0:00:06m0:00:0100:01
# Installing collected packages: nvidia-nccl-cu12, xgboost
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [xgboost]m1/2 [xgboost]
# Successfully installed nvidia-nccl-cu12-2.30.4 xgboost-3.2.0
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# use xgboost to make a model and then get feature importances
import xgboost as xgb

# create X and y
X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(
    X.assign(**X.select_dtypes(object).astype('category')),
    y, random_state=42)

xg = xgb.XGBRegressor(enable_categorical=True, random_state=42)
xg.fit(X_train, y_train)
xg.score(X_test, y_test)
# Out:
# 0.9933781027793884

# %%
pd.Series(xg.feature_importances_, index=X_train.columns).sort_values().tail(25).plot.barh()
# Out:
# <Axes: >

# %%
# scatter plot range vs city mpg
(autos
 .plot.scatter(x='range', y='city08')
)
# Out:
# <Axes: xlabel='range', ylabel='city08'>

# %%
pd.Series(xg.feature_importances_, index=X_train.columns).sort_values().iloc[:-1].plot.barh()
# Out:
# <Axes: >

# %%
# make xg model with just range, barrels08, fuelType, and cylinders
xg_simple = xgb.XGBRegressor(enable_categorical=True, random_state=42)
xg_simple.fit(X_train[['range', 'barrels08', 'fuelType', 'cylinders']], y_train)
xg_simple.score(X_test[['range', 'barrels08', 'fuelType', 'cylinders']], y_test)
# Out:
# 0.9946529269218445

# %% [markdown]
# ## Recursive Feature Elimination
#
# *Recursive feature elimination* (RFE) is a feature selection method that fits a model and removes the weakest feature (or features) until the specified number of features is reached. It is a greedy optimization algorithm that aims to find the best performing feature subset.

# %%
from sklearn.feature_selection import RFE

# use rfe with xgboost
xg_model = xgb.XGBRegressor(enable_categorical=True, random_state=42)
rfe = RFE(xg_model, n_features_to_select=3)

X = autos.drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(
    #X.assign(**X.select_dtypes('string[pyarrow]').astype('category')),
    X.select_dtypes('number'),
    y, random_state=42)

rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=XGBRegressor(base_score=None, booster=None, callbacks=None,
#                            colsample_bylevel=None, colsample_bynode=None,
#                            colsample_bytree=None, device=None,
#                            early_stopping_rounds=None, enable_categorical=True,
#                            eval_metric=None, feature_types=None,
#                            feature_weights=None, gamma=None, grow_policy=None,
#                            importance_type=None, interaction_constraints=None,
#                            learning_rate=None, max_bin=None,
#                            max_cat_threshold=None, max_cat_to_onehot=None,
#                            max_delta_step=None, max_depth=None, max_leaves=None,
#                            min_child_weight=None, missing=nan,
#                            monotone_constraints=None, multi_strategy=None,
#                            n_estimators=None, n_jobs=None,
#                            num_parallel_tree=None, ...),
#     n_features_to_select=3)

# %%
# Explore the API to determine which features were selected
rfe?
# Out:
# Type:        RFE
# String form:
# RFE(estimator=XGBRegressor(base_score=None, booster=None, callbacks=None,
#            <...> n_jobs=None,
#            num_parallel_tree=None, ...),
#            n_features_to_select=3)
# File:        /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/feature_selection/_rfe.py
# Docstring:
# Feature ranking with recursive feature elimination.
#
# Given an external estimator that assigns weights to features (e.g., the
# coefficients of a linear model), the goal of recursive feature elimination
# (RFE) is to select features by recursively considering smaller and smaller
# sets of features. First, the estimator is trained on the initial set of
# features and the importance of each feature is obtained either through
# any specific attribute or callable.
# Then, the least important features are pruned from current set of features.
# That procedure is recursively repeated on the pruned set until the desired
# number of features to select is eventually reached.
#
# Read more in the :ref:`User Guide <rfe>`.
#
# Parameters
# ----------
# estimator : ``Estimator`` instance
#     A supervised learning estimator with a ``fit`` method that provides
#     information about feature importance
#     (e.g. `coef_`, `feature_importances_`).
#
# n_features_to_select : int or float, default=None
#     The number of features to select. If `None`, half of the features are
#     selected. If integer, the parameter is the absolute number of features
#     to select. If float between 0 and 1, it is the fraction of features to
#     select.
#
#     .. versionchanged:: 0.24
#        Added float values for fractions.
#
# step : int or float, default=1
#     If greater than or equal to 1, then ``step`` corresponds to the
#     (integer) number of features to remove at each iteration.
#     If within (0.0, 1.0), then ``step`` corresponds to the percentage
#     (rounded down) of features to remove at each iteration.
#
# verbose : int, default=0
#     Controls verbosity of output.
#
# importance_getter : str or callable, default='auto'
#     If 'auto', uses the feature importance either through a `coef_`
#     or `feature_importances_` attributes of estimator.
#
#     Also accepts a string that specifies an attribute name/path
#     for extracting feature importance (implemented with `attrgetter`).
#     For example, give `regressor_.coef_` in case of
#     :class:`~sklearn.compose.TransformedTargetRegressor`  or
#     `named_steps.clf.feature_importances_` in case of
#     class:`~sklearn.pipeline.Pipeline` with its last step named `clf`.
#
#     If `callable`, overrides the default feature importance getter.
#     The callable is passed with the fitted estimator and it should
#     return importance for each feature.
#
#     .. versionadded:: 0.24
#
# Attributes
# ----------
# classes_ : ndarray of shape (n_classes,)
#     The classes labels. Only available when `estimator` is a classifier.
#
# estimator_ : ``Estimator`` instance
#     The fitted estimator used to select features.
#
# n_features_ : int
#     The number of selected features.
#
# n_features_in_ : int
#     Number of features seen during :term:`fit`. Only defined if the
#     underlying estimator exposes such an attribute when fit.
#
#     .. versionadded:: 0.24
#
# feature_names_in_ : ndarray of shape (`n_features_in_`,)
#     Names of features seen during :term:`fit`. Defined only when `X`
#     has feature names that are all strings.
#
#     .. versionadded:: 1.0
#
# ranking_ : ndarray of shape (n_features,)
#     The feature ranking, such that ``ranking_[i]`` corresponds to the
#     ranking position of the i-th feature. Selected (i.e., estimated
#     best) features are assigned rank 1.
#
# support_ : ndarray of shape (n_features,)
#     The mask of selected features.
#
# See Also
# --------
# RFECV : Recursive feature elimination with built-in cross-validated
#     selection of the best number of features.
# SelectFromModel : Feature selection based on thresholds of importance
#     weights.
# SequentialFeatureSelector : Sequential cross-validation based feature
#     selection. Does not rely on importance weights.
#
# Notes
# -----
# Allows NaN/Inf in the input if the underlying estimator does as well.
#
# References
# ----------
#
# .. [1] Guyon, I., Weston, J., Barnhill, S., & Vapnik, V., "Gene selection
#        for cancer classification using support vector machines",
#        Mach. Learn., 46(1-3), 389--422, 2002.
#
# Examples
# --------
# The following example shows how to retrieve the 5 most informative
# features in the Friedman #1 dataset.
#
# >>> from sklearn.datasets import make_friedman1
# >>> from sklearn.feature_selection import RFE
# >>> from sklearn.svm import SVR
# >>> X, y = make_friedman1(n_samples=50, n_features=10, random_state=0)
# >>> estimator = SVR(kernel="linear")
# >>> selector = RFE(estimator, n_features_to_select=5, step=1)
# >>> selector = selector.fit(X, y)
# >>> selector.support_
# array([ True,  True,  True,  True,  True, False, False, False, False,
#        False])
# >>> selector.ranking_
# array([1, 1, 1, 1, 1, 6, 4, 3, 2, 5])

# %%
pd.DataFrame({'features':X_train.columns,
              'support': rfe.support_,
              'ranking':rfe.ranking_}).sort_values('ranking')
# Out:
#      features  support  ranking
# 1   barrels08     True        1
# 4       displ     True        1
# 5  fuelCost08     True        1
# 3   cylinders    False        2
# 2       range    False        3
# 0        year    False        4

# %%
# make model with barrels08, range, and fuelCost08
xg_simple = xgb.XGBRegressor(enable_categorical=True, random_state=42)
xg_simple.fit(X_train[['barrels08', 'range', 'fuelCost08']], y_train)
xg_simple.score(X_test[['barrels08', 'range', 'fuelCost08']], y_test)
# Out:
# 0.9955587387084961

# %% [markdown]
# ## Adding a Random Column
#
# Another technique is to add a column of random numbers. We should be able to drop any columns that perform worse than the random column.

# %%
# create X and add a random column
X = (autos
     .drop(columns=['city08', 'highway08', 'comb08', 'createdOn', 'offset', 'str_date'])
     .assign(random=lambda df: np.random.random(size=len(df)))
     )

y = autos.city08

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(
    X.assign(**X.select_dtypes(object).astype('category')),
    y, random_state=42)

xg = xgb.XGBRegressor(enable_categorical=True, random_state=42)
xg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# look at feature importances
# In this case the random column is the least important 
pd.Series(xg.feature_importances_, index=X_train.columns).sort_values().plot.barh()
# Out:
# <Axes: >

# %% [markdown]
# ## Challenge: Feature Selection
# Apply
#  RFE to linear regression model to limit model to 5 columns

# %% [markdown]
# ## Solution: Feature Selection

# %% [markdown]
# # Airline Passenger Prediction
#
# Using the airline data, create a linear regression model to predict the number of passengers for the next month based on the current month. Then make another model using the `seasonal_decompose` function to add a seasonality component to the model.

# %% [markdown]
# ## Solution: Airline Passenger Prediction

# %%
# Load airline data
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose

# Load the data (assuming it's already loaded as 'air' from previous cells)
# If not, uncomment the following:
# airlines = pd.read_html('data/Passengers_2024.xls')
# raw = airlines[0]
# def tweak_airline(df_):
#     return (df_
#             .query('Month != "TOTAL"')
#             .astype({'Month': 'int64'})
#             .assign(date=lambda df: pd.to_datetime(df[['Year', 'Month']].assign(day=1)))
#     )
# air = tweak_airline(raw)

# Display the first few rows
air.head()
# Out:
#    Year  Month  DOMESTIC  INTERNATIONAL     TOTAL       date
# 0  2002     10  48054917        9578435  57633352 2002-10-01
# 1  2002     11  44850246        9016535  53866781 2002-11-01
# 2  2002     12  49684353       10038794  59723147 2002-12-01
# 4  2003      1  43032450        9726436  52758886 2003-01-01
# 5  2003      2  41166780        8283372  49450152 2003-02-01

# %%
# Simple linear regression model: predict next month's passengers from current month
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Create X and y for simple model
X_simple = air[['DOMESTIC']].iloc[:-1]  # Current month passengers
y_simple = air.DOMESTIC.shift(-1).iloc[:-1]  # Next month passengers

# Split into train and test (time series split)
X_train_simple, X_test_simple, y_train_simple, y_test_simple = train_test_split(
    X_simple, y_simple, shuffle=False, test_size=0.2
)

# Fit simple model
simple_model = LinearRegression()
simple_model.fit(X_train_simple, y_train_simple)

# Predict and evaluate
y_pred_simple = simple_model.predict(X_test_simple)
simple_mse = mean_squared_error(y_test_simple, y_pred_simple)
simple_rmse = np.sqrt(simple_mse)
simple_r2 = r2_score(y_test_simple, y_pred_simple)

print("Simple Linear Regression Model:")
print(f"MSE: {simple_mse:.2f}")
print(f"RMSE: {simple_rmse:.2f}")
print(f"R²: {simple_r2:.3f}")
# Out:
# Simple Linear Regression Model:
# MSE: 77557957898965.59
# RMSE: 8806699.60
# R²: 0.789

# %%
# Seasonal decomposition model
# Add trend, seasonal, and residual components as features
X_seasonal = (air
    .assign(trend=lambda df: seasonal_decompose(df.DOMESTIC, model='additive', period=12).trend,
            seasonal=lambda df: seasonal_decompose(df.DOMESTIC, model='additive', period=12).seasonal,
            resid=lambda df: seasonal_decompose(df.DOMESTIC, model='additive', period=12).resid)
    .loc[:, ['trend', 'seasonal', 'resid', 'DOMESTIC']]
    .iloc[12:-12]  # Remove leading/trailing NaNs from decomposition
)

y_seasonal = air.DOMESTIC.shift(-1).loc[X_seasonal.index]

# Split into train and test
X_train_seasonal, X_test_seasonal, y_train_seasonal, y_test_seasonal = train_test_split(
    X_seasonal, y_seasonal, shuffle=False, test_size=0.2
)

# Fit seasonal model
seasonal_model = LinearRegression()
seasonal_model.fit(X_train_seasonal, y_train_seasonal)

# Predict and evaluate
y_pred_seasonal = seasonal_model.predict(X_test_seasonal)
seasonal_mse = mean_squared_error(y_test_seasonal, y_pred_seasonal)
seasonal_rmse = np.sqrt(seasonal_mse)
seasonal_r2 = r2_score(y_test_seasonal, y_pred_seasonal)

print("Seasonal Decomposition Model:")
print(f"MSE: {seasonal_mse:.2f}")
print(f"RMSE: {seasonal_rmse:.2f}")
print(f"R²: {seasonal_r2:.3f}")

print("\nModel Comparison:")
print(f"Simple Model R²: {simple_r2:.3f}")
print(f"Seasonal Model R²: {seasonal_r2:.3f}")
print(f"Improvement: {seasonal_r2 - simple_r2:.3f}")
# Out:
# Seasonal Decomposition Model:
# MSE: 90337568167505.67
# RMSE: 9504607.73
# R²: 0.764
#
# Model Comparison:
# Simple Model R²: 0.789
# Seasonal Model R²: 0.764
# Improvement: -0.025

# %% [markdown]
# ## Conclusion
#
# In this case, the simple linear regression model performed better (R² = 0.789) than the seasonal decomposition model (R² = 0.764). This suggests that for this particular dataset, the autoregressive relationship captures the pattern more effectively than explicitly modeling the trend, seasonal, and residual components. However, seasonal decomposition can be valuable for understanding the underlying components of time series data and may perform better on different datasets or with different feature engineering approaches.

# %% [markdown]
# # Conclusion - Next Steps
#
# - Practice! - Watching and listening is not enough. You need to practice what you have learned.
# - Understand your data - You need to understand your data and the problem you are trying to solve.
# - Master Pandas and Scikit-Learn - These are the most important tools for feature engineering.
